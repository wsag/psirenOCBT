# %%
from itertools import product
import pandas as pd
from scipy import stats
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import pytz
import os
from glob import glob
from itertools import combinations,chain
import statsmodels.formula.api as smf
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import summary_table
from statsmodels.stats.outliers_influence import variance_inflation_factor as vif
from patsy import dmatrices

# %%
watersheds=["anacostia","don","ipswich","miami","chicago","socal","sfbay"]
ws_names={"anacostia":"Anacostia","don":"Don","ipswich":"Ipswich","miami":"Miami","chicago":"N.Chicago","socal":"S.California","sfbay":"Walnut"}

# %%
root="/mnt/c/Users/soggy/OneDrive - USNH/Dox/PSIREN/ocBottleTracker/" # Change to user directory
fldr=root+"supportingData/"
distances = pd.read_csv(fldr+f"allsites_bottleTracker_Movement_Summary_NHD.txt",sep="\t",index_col=[0,1,2],parse_dates=True)
# Out:
# /tmp/ipykernel_907/3563730602.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   distances = pd.read_csv(fldr+f"allsites_bottleTracker_Movement_Summary_NHD.txt",sep="\t",index_col=[0,1,2],parse_dates=True)
# /tmp/ipykernel_907/3563730602.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   distances = pd.read_csv(fldr+f"allsites_bottleTracker_Movement_Summary_NHD.txt",sep="\t",index_col=[0,1,2],parse_dates=True)

# %%
distances.index.names = "watershed Asset dt".split()

# %%
print ( (distances['len_m'] > 10000.).sum() )
print( (distances['len_m'] > 1000.).sum() )
print( (distances['len_m'] > 0.).sum() )
# Out:
# 9
# 222
# 1288

# %%
distances
# Out:
#                                                          site_no  \
# watershed Asset              dt
# chicago   Clyde              2022-09-12 10:57:43-05:00  05535000
#                              2022-10-11 05:02:01-05:00  05535000
#                              2022-10-30 11:11:29-05:00  05535000
#           Caleb              2022-11-17 04:10:10-06:00  05535000
#           Cassidy            2022-09-15 23:01:51-05:00  05535000
# ...                                                          ...
# socal     Periwinkle_1_1     2024-02-05 06:00:50-08:00  11048600
#                              2024-02-07 09:58:50-08:00  11048600
#                              2024-02-08 09:51:31-08:00  11048600
#                              2024-02-09 13:58:32-08:00  11048600
#           Skip Jack Tuna_1_1 2024-02-05 11:04:20-08:00  11048600
#
#                                                                len_m  \
# watershed Asset              dt
# chicago   Clyde              2022-09-12 10:57:43-05:00    912.820429
#                              2022-10-11 05:02:01-05:00      7.874707
#                              2022-10-30 11:11:29-05:00      5.114577
#           Caleb              2022-11-17 04:10:10-06:00     10.168867
#           Cassidy            2022-09-15 23:01:51-05:00      5.126566
# ...                                                              ...
# socal     Periwinkle_1_1     2024-02-05 06:00:50-08:00   2797.258326
#                              2024-02-07 09:58:50-08:00     52.850129
#                              2024-02-08 09:51:31-08:00     38.190741
#                              2024-02-09 13:58:32-08:00     36.696395
#           Skip Jack Tuna_1_1 2024-02-05 11:04:20-08:00  12908.641794
#
#                                                                lon        lat  \
# watershed Asset              dt
# chicago   Clyde              2022-09-12 10:57:43-05:00  -87.854285  42.249377
#                              2022-10-11 05:02:01-05:00  -87.854273  42.249353
#                              2022-10-30 11:11:29-05:00  -87.854307  42.249419
#           Caleb              2022-11-17 04:10:10-06:00  -87.857014  42.259590
#           Cassidy            2022-09-15 23:01:51-05:00  -87.854373  42.249547
# ...                                                            ...        ...
# socal     Periwinkle_1_1     2024-02-05 06:00:50-08:00 -117.868275  33.650383
#                              2024-02-07 09:58:50-08:00 -117.877723  33.648525
#                              2024-02-08 09:51:31-08:00 -117.877786  33.648529
#                              2024-02-09 13:58:32-08:00 -117.878522  33.648575
#           Skip Jack Tuna_1_1 2024-02-05 11:04:20-08:00 -117.902756  33.619086
#
#                                                         totdasqkm  sinuosity  \
# watershed Asset              dt
# chicago   Clyde              2022-09-12 10:57:43-05:00    26.1928   0.789986
#                              2022-10-11 05:02:01-05:00    26.1928   0.789986
#                              2022-10-30 11:11:29-05:00    26.1928   0.789986
#           Caleb              2022-11-17 04:10:10-06:00    26.1928   0.789986
#           Cassidy            2022-09-15 23:01:51-05:00    26.1928   0.789986
# ...                                                           ...        ...
# socal     Periwinkle_1_1     2024-02-05 06:00:50-08:00   275.4389   1.027011
#                              2024-02-07 09:58:50-08:00   275.4389   1.027011
#                              2024-02-08 09:51:31-08:00   275.4389   1.027011
#                              2024-02-09 13:58:32-08:00   275.4389   1.027011
#           Skip Jack Tuna_1_1 2024-02-05 11:04:20-08:00 -9999.0000   3.254901
#
#                                                         slope10m  u_slope10m  \
# watershed Asset              dt
# chicago   Clyde              2022-09-12 10:57:43-05:00  0.017929    0.028176
#                              2022-10-11 05:02:01-05:00  0.017929    0.028176
#                              2022-10-30 11:11:29-05:00  0.017929    0.028176
#           Caleb              2022-11-17 04:10:10-06:00  0.017929    0.028176
#           Cassidy            2022-09-15 23:01:51-05:00  0.017929    0.028176
# ...                                                          ...         ...
# socal     Periwinkle_1_1     2024-02-05 06:00:50-08:00  0.000367    0.001457
#                              2024-02-07 09:58:50-08:00  0.000367    0.001457
#                              2024-02-08 09:51:31-08:00  0.000367    0.001457
#                              2024-02-09 13:58:32-08:00  0.000367    0.001457
#           Skip Jack Tuna_1_1 2024-02-05 11:04:20-08:00  0.026778    0.070154
#
#                                                          slope_mean  \
# watershed Asset              dt
# chicago   Clyde              2022-09-12 10:57:43-05:00     0.001263
#                              2022-10-11 05:02:01-05:00     0.001263
#                              2022-10-30 11:11:29-05:00     0.001263
#           Caleb              2022-11-17 04:10:10-06:00     0.001263
#           Cassidy            2022-09-15 23:01:51-05:00     0.001263
# ...                                                             ...
# socal     Periwinkle_1_1     2024-02-05 06:00:50-08:00     0.000362
#                              2024-02-07 09:58:50-08:00     0.000362
#                              2024-02-08 09:51:31-08:00     0.000362
#                              2024-02-09 13:58:32-08:00     0.000362
#           Skip Jack Tuna_1_1 2024-02-05 11:04:20-08:00 -9998.000000
#
#                                                         slope_std     00060  \
# watershed Asset              dt
# chicago   Clyde              2022-09-12 10:57:43-05:00        0.0       NaN
#                              2022-10-11 05:02:01-05:00        0.0  0.038794
#                              2022-10-30 11:11:29-05:00        0.0  0.096560
#           Caleb              2022-11-17 04:10:10-06:00        0.0  1.206298
#           Cassidy            2022-09-15 23:01:51-05:00        0.0  0.543683
# ...                                                           ...       ...
# socal     Periwinkle_1_1     2024-02-05 06:00:50-08:00        0.0  4.474062
#                              2024-02-07 09:58:50-08:00        0.0  0.464396
#                              2024-02-08 09:51:31-08:00        0.0  0.419089
#                              2024-02-09 13:58:32-08:00        0.0  0.216624
#           Skip Jack Tuna_1_1 2024-02-05 11:04:20-08:00        0.0  6.314657
#
#                                                          tt_days       Q_m3s  \
# watershed Asset              dt
# chicago   Clyde              2022-09-12 10:57:43-05:00  0.500903         NaN
#                              2022-10-11 05:02:01-05:00  0.246424    0.030152
#                              2022-10-30 11:11:29-05:00  0.246134    0.075050
#           Caleb              2022-11-17 04:10:10-06:00  0.239213    0.937576
#           Cassidy            2022-09-15 23:01:51-05:00  0.261435    0.422569
# ...                                                          ...         ...
# socal     Periwinkle_1_1     2024-02-05 06:00:50-08:00  0.338600    3.839036
#                              2024-02-07 09:58:50-08:00  0.161933    0.398482
#                              2024-02-08 09:51:31-08:00  0.334387    0.359606
#                              2024-02-09 13:58:32-08:00  0.324155    0.185877
#           Skip Jack Tuna_1_1 2024-02-05 11:04:20-08:00  0.125289 -196.698608
#
#                                                               omega0  \
# watershed Asset              dt
# chicago   Clyde              2022-09-12 10:57:43-05:00           NaN
#                              2022-10-11 05:02:01-05:00  4.791024e-02
#                              2022-10-30 11:11:29-05:00  1.192510e-01
#           Caleb              2022-11-17 04:10:10-06:00  1.489764e+00
#           Cassidy            2022-09-15 23:01:51-05:00  6.714428e-01
# ...                                                              ...
# socal     Periwinkle_1_1     2024-02-05 06:00:50-08:00  5.145746e-01
#                              2024-02-07 09:58:50-08:00  5.341154e-02
#                              2024-02-08 09:51:31-08:00  4.820066e-02
#                              2024-02-09 13:58:32-08:00  2.491453e-02
#           Skip Jack Tuna_1_1 2024-02-05 11:04:20-08:00 -7.062554e+06
#
#                                                                Q2h  \
# watershed Asset              dt
# chicago   Clyde              2022-09-12 10:57:43-05:00         NaN
#                              2022-10-11 05:02:01-05:00    0.033013
#                              2022-10-30 11:11:29-05:00    0.075050
#           Caleb              2022-11-17 04:10:10-06:00    1.016808
#           Cassidy            2022-09-15 23:01:51-05:00    0.453382
# ...                                                            ...
# socal     Periwinkle_1_1     2024-02-05 06:00:50-08:00    4.300693
#                              2024-02-07 09:58:50-08:00    0.415491
#                              2024-02-08 09:51:31-08:00    0.415491
#                              2024-02-09 13:58:32-08:00    0.198512
#           Skip Jack Tuna_1_1 2024-02-05 11:04:20-08:00 -208.165343
#
#                                                                Q4h  \
# watershed Asset              dt
# chicago   Clyde              2022-09-12 10:57:43-05:00         NaN
#                              2022-10-11 05:02:01-05:00    0.033013
#                              2022-10-30 11:11:29-05:00    0.075050
#           Caleb              2022-11-17 04:10:10-06:00    1.038817
#           Cassidy            2022-09-15 23:01:51-05:00    0.484194
# ...                                                            ...
# socal     Periwinkle_1_1     2024-02-05 06:00:50-08:00    5.807150
#                              2024-02-07 09:58:50-08:00    0.456797
#                              2024-02-08 09:51:31-08:00    0.519971
#                              2024-02-09 13:58:32-08:00    0.198512
#           Skip Jack Tuna_1_1 2024-02-05 11:04:20-08:00 -208.165343
#
#                                                               Q12h  \
# watershed Asset              dt
# chicago   Clyde              2022-09-12 10:57:43-05:00         NaN
#                              2022-10-11 05:02:01-05:00    0.035874
#                              2022-10-30 11:11:29-05:00    0.080112
#           Caleb              2022-11-17 04:10:10-06:00    1.146660
#           Cassidy            2022-09-15 23:01:51-05:00    0.706483
# ...                                                            ...
# socal     Periwinkle_1_1     2024-02-05 06:00:50-08:00    7.313607
#                              2024-02-07 09:58:50-08:00    2.551258
#                              2024-02-08 09:51:31-08:00    4.033418
#                              2024-02-09 13:58:32-08:00    0.255126
#           Skip Jack Tuna_1_1 2024-02-05 11:04:20-08:00 -265.499018
#
#                                                               Q24h Point_ID
# watershed Asset              dt
# chicago   Clyde              2022-09-12 10:57:43-05:00         NaN    p0001
#                              2022-10-11 05:02:01-05:00    0.035874    p0002
#                              2022-10-30 11:11:29-05:00    0.096839    p0003
#           Caleb              2022-11-17 04:10:10-06:00    1.146660    p0004
#           Cassidy            2022-09-15 23:01:51-05:00    1.146660    p0005
# ...                                                            ...      ...
# socal     Periwinkle_1_1     2024-02-05 06:00:50-08:00    7.313607    p1284
#                              2024-02-07 09:58:50-08:00    7.216416    p1285
#                              2024-02-08 09:51:31-08:00    4.033418    p1286
#                              2024-02-09 13:58:32-08:00    0.289143    p1287
#           Skip Jack Tuna_1_1 2024-02-05 11:04:20-08:00 -265.499018    p1288
#
# [1288 rows x 19 columns]

# %% [markdown]
# Now a bunch of watershed properties are calculated using networkTools on UNH Servers, tabulated, saved to the "lc" subdirectory, and are joined here.

# %%
lcs={"21":"Developed (Open)","22":"Developed (Low)","23":"Developed (Med.)","24":"Developed (High)","22_23_24":"Developed (Sum)",
     "31": "Barren","41": "Decid. Forest", "42": "Evergreen Forest", "43": "Mixed Forest", "41_42_43": "Forest", 
     "52": "Shrub/Scrub", "71": "Grassland" ,"81": "Pasture","82": "Row Crops","90": "Woody Wetlands", "95": "Herbaceous Wetlands"}
LCs=dict([(k,{}) for k in ws_names.keys() ])
for ws,lc in product(ws_names.keys(),lcs.keys()):
    L=pd.read_csv(fldr+'lc/{}_extract_{}.csv'.format(ws,lc),sep="\t",index_col="Site_ID")
    LCs[ws][lc]=L

# %%
lcs={"21":"Developed (Open)","22":"Developed (Low)","23":"Developed (Med.)","24":"Developed (High)","22_23_24":"Developed (Sum)",
     "31": "Barren","41": "Decid. Forest", "42": "Evergreen Forest", "43": "Mixed Forest", "41_42_43": "Forest", 
     "52": "Shrub/Scrub", "71": "Grassland" ,"81": "Pasture","82": "Row Crops","90": "Woody Wetlands", "95": "Herbaceous Wetlands"}

# %%
LC=pd.concat(dict([(k,pd.concat(LCs[k])) for k in LCs.keys()]))
LC=LC.xs("Data",axis=1).unstack(level=1).reset_index(level=0)
LC.index = LC.index.rename("Point_ID")
lcdistances=distances.join(LC,on="Point_ID")

# %%
# Filling in Don's land-cover from Schwenk et al. 2025
psiren_2_trca_sites={"PR":"HY019","YM":"HY022","TC":"HY062","GM":"HY113"}
don_lc={"HY019":{"22_23_24":80.66, "31":1.73, "41_42_43":9.57, "90":0.4, "82":4.6, "52":2.83},
 "HY062":{"22_23_24":90.71,"31":1.1,"41_42_43":5.3,"90":0.22, "82":0.42,"52":2.25},
 "HY022":{"22_23_24":77.32, "31":1.81, "41_42_43":11.23, "90":0.45,"82":6.01, "52":3.01},
 "HY113": {"22_23_24":85.71,"31":1.08, "41_42_43":5.59, "90":0.63, "82":3.98,"52":3.0}
}
don_lc=pd.DataFrame.from_dict(don_lc,orient="index")
# Invent naive estimates for other landcover classes
for lc in "22 23 24".split():
    don_lc[lc]=don_lc["22_23_24"]/4.
don_lc['21']=don_lc["22_23_24"]/4.
for lc in "41 42 43".split():
    don_lc[lc]=don_lc["41_42_43"]/3.
don_lc["71"]=0.
don_lc['81']=0.
don_lc['95']=0.

# %%
for site,row in don_lc.iterrows():
    for col,val in row.items():
        print(site,col,val)
        lcdistances.loc[lcdistances["site_no"]==site,col] = val
# Out:
# HY019 22_23_24 80.66
# HY019 31 1.73
# HY019 41_42_43 9.57
# HY019 90 0.4
# HY019 82 4.6
# HY019 52 2.83
# HY019 22 20.165
# HY019 23 20.165
# HY019 24 20.165
# HY019 21 20.165
# HY019 41 3.19
# HY019 42 3.19
# HY019 43 3.19
# HY019 71 0.0
# HY019 81 0.0
# HY019 95 0.0
# HY062 22_23_24 90.71
# HY062 31 1.1
# HY062 41_42_43 5.3
# HY062 90 0.22
# HY062 82 0.42
# HY062 52 2.25
# HY062 22 22.6775
# HY062 23 22.6775
# HY062 24 22.6775
# HY062 21 22.6775
# HY062 41 1.7666666666666666
# HY062 42 1.7666666666666666
# HY062 43 1.7666666666666666
# HY062 71 0.0
# HY062 81 0.0
# HY062 95 0.0
# HY022 22_23_24 77.32
# HY022 31 1.81
# HY022 41_42_43 11.23
# HY022 90 0.45
# HY022 82 6.01
# HY022 52 3.01
# HY022 22 19.33
# HY022 23 19.33
# HY022 24 19.33
# HY022 21 19.33
# HY022 41 3.7433333333333336
# HY022 42 3.7433333333333336
# HY022 43 3.7433333333333336
# HY022 71 0.0
# HY022 81 0.0
# HY022 95 0.0
# HY113 22_23_24 85.71
# HY113 31 1.08
# HY113 41_42_43 5.59
# HY113 90 0.63
# HY113 82 3.98
# HY113 52 3.0
# HY113 22 21.4275
# HY113 23 21.4275
# HY113 24 21.4275
# HY113 21 21.4275
# HY113 41 1.8633333333333333
# HY113 42 1.8633333333333333
# HY113 43 1.8633333333333333
# HY113 71 0.0
# HY113 81 0.0
# HY113 95 0.0

# %%
lcdistances.loc[lcdistances["totdasqkm"]<0,'totdasqkm']=np.nan
lcdistances.loc[lcdistances['Q_m3s']<0,'Q_m3s']=np.nan
lcdistances.loc[lcdistances['slope_mean']<0,'slope_mean']=np.nan
lcdistances.loc[lcdistances['slope10m'] <0,'slope10m']=np.nan
lcdistances.loc[lcdistances['u_slope10m'] <0,'u_slope10m']=np.nan
lcdistances.loc[lcdistances['sinuosity']<1,'sinuosity']=1.001

# %%
lcdistclean=lcdistances.dropna()

# %% [markdown]
# WE have a lot of potential descriptors of our travel distances.  There is a forest of potential models we could create.  Use Gradient Boosted Trees to try to evaluate the importance of models.

# %% [markdown]
# We want to start looking into the possibility of using multiple indicator variables to describe what's happening.

# %%
lcs["Q_m3s"] = r"Q ($m^3\ s^{-1}$)"
lcs["u_slope10m"] = "slope10m.std"

# %%
import shap
from sklearn import ensemble
import sklearn.metrics as skmetrics
from sklearn.model_selection import train_test_split
from sklearn.inspection import permutation_importance
from sklearn.utils.fixes import parse_version
temp = lcdistclean.set_index("site_no",append=True).drop(columns=['Point_ID','level_0'])
print(temp.columns)
temp["sinuosity"] = temp['sinuosity'].clip(lower=1.00001)
temp["open"] = temp["41_42_43"]+temp["52"]+temp["21"]+temp["71"]+temp["81"]
temp = temp.dropna()
temp["omega0"]=temp['omega0'].astype(float)
y=temp["len_m"].values

drop_cols = ['Q2h', 'Q4h','Q12h', 'Q24h','00060','lon','lat','tt_days','omega0','slope_std','slope_mean','totdasqkm','22','23','24','41','42','43']
temp = temp.drop(columns=drop_cols)


X=temp[[x for x in temp.columns if x != "len_m"]]
names=X.columns
#X=X.values
X = np.log(X.clip(lower=1e-7))
y = np.log(y)
X_train,X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=3)
params = {"n_estimators":50, "max_depth":5,"min_samples_split":3,"learning_rate":0.1,"loss":"huber",'random_state':116}
reg = ensemble.GradientBoostingRegressor(**params)
reg.fit(X_train,y_train)
r2 = skmetrics.r2_score(y_test,reg.predict(X_test))
print("The r2 on the test set: {:0.4f}".format(r2))
mse = skmetrics.mean_squared_error(y_test,reg.predict(X_test))
print("The mse on the test set: {:0.4f}".format(mse))
feature_importance = reg.feature_importances_
sorted_idx = np.argsort(feature_importance)
pos = np.arange(sorted_idx.shape[0]) + 0.5
fig = plt.figure(figsize=(12, 6),dpi=300)
plt.subplot(1, 2, 1)
plt.barh(pos, feature_importance[sorted_idx], align="center")
plt.yticks(pos, [lcs[x] if x in lcs.keys() else x for x in X.columns[sorted_idx]]) # X.columns[sorted_idx]) #
plt.title("Feature Importance (MDI)")

result = permutation_importance(
    reg, X_test, y_test, n_repeats=10, random_state=42, n_jobs=2
)
sorted_idx = result.importances_mean.argsort()
plt.subplot(1, 2, 2)

# `labels` argument in boxplot is deprecated in matplotlib 3.9 and has been
# renamed to `tick_labels`. The following code handles this, but as a
# scikit-learn user you probably can write simpler code by using `labels=...`
# (matplotlib < 3.9) or `tick_labels=...` (matplotlib >= 3.9).
tick_labels_parameter_name = (
    "tick_labels"
    if parse_version(mpl.__version__) >= parse_version("3.9")
    else "labels"
)
tick_labels_dict = {
    tick_labels_parameter_name: [lcs[x] if x in lcs.keys() else x for x in X.columns[sorted_idx]]
}
plt.boxplot(result.importances[sorted_idx].T, vert=False, **tick_labels_dict)
plt.title("Permutation Importance (test set)")
fig.tight_layout()
plt.show()
# Out:
# Index(['len_m', 'lon', 'lat', 'totdasqkm', 'sinuosity', 'slope10m',
#        'u_slope10m', 'slope_mean', 'slope_std', '00060', 'tt_days', 'Q_m3s',
#        'omega0', 'Q2h', 'Q4h', 'Q12h', 'Q24h', '21', '22', '23', '24',
#        '22_23_24', '31', '41', '42', '43', '41_42_43', '52', '71', '81', '82',
#        '90', '95'],
#       dtype='object')
# The r2 on the test set: 0.4099
# The mse on the test set: 2.9192

# %%
fig,ax=plt.subplots(1,1)
# Create SHAP explainer
explainer = shap.Explainer(reg.predict, X_train,seed=506)

# Calculate SHAP values
shap_values = explainer(X_test)

# Plot summary
shap.summary_plot(shap_values, X_test,feature_names=[lcs[x] if x in lcs.keys() else x for x in X])
fig=plt.gcf()
fig.set_dpi(600)
fig.set_size_inches((5,3))
# Out:
# PermutationExplainer explainer: 250it [00:26,  8.41it/s]
# /tmp/ipykernel_907/1676048455.py:9: FutureWarning: The NumPy global RNG was seeded by calling `np.random.seed`. In a future version this function will no longer use the global RNG. Pass `rng` explicitly to opt-in to the new behaviour and silence this warning.
#   shap.summary_plot(shap_values, X_test,feature_names=[lcs[x] if x in lcs.keys() else x for x in X])

# %%
# Dependence plots

for feature in ["Q_m3s", "41_42_43", "sinuosity", "95", "22_23_24", "82"]:
    print(feature)
    shap.dependence_plot(feature, shap_values.values, X_test)
# Out:
# Q_m3s
# 41_42_43
# sinuosity
# 95
# 22_23_24
# 82

# %%
# Look at interaction plots

#Compute SHAP interaction values
tree_explainer = shap.TreeExplainer(reg)
interaction_values = tree_explainer.shap_interaction_values(X_test)

target_features = ["Q_m3s", "41_42_43", "sinuosity", "95", "22_23_24", "82"]

feature_names = X_test.columns.tolist()

for f1,f2 in product(target_features,target_features):
    if f1 == f2:
        continue
    i_f1 = feature_names.index(f1)
    i_f2 = feature_names.index(f2)


    # Extract interaction values for 'sinuosity'
    sinuosity_interactions = interaction_values[:, i_f1, i_f2]
    
    # Plot using raw SHAP values for 'sinuosity' and color by '41_42_43'
    shap.dependence_plot(
        i_f1,  # index of 'sinuosity'
        interaction_values[:, :, i_f2],  # SHAP values for all features interacting with '41_42_43'
        X_test,
        interaction_index=i_f2  # color by '41_42_43'
    )

# %%
import shap
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming you have:
# - reg: your trained tree-based model
# - X_test: your test dataset as a DataFrame

# Create TreeExplainer and compute interaction values
explainer = shap.TreeExplainer(reg)

#X_int = X_test[target_features]
interaction_values = explainer.shap_interaction_values(X_test)

# Convert to numpy array and take absolute values
interaction_array = np.abs(np.array(interaction_values))

# Average across all samples to get global interaction matrix
interaction_matrix = interaction_array.mean(axis=0)

# Plot the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(interaction_matrix, xticklabels=X_test.columns, yticklabels=X_test.columns,
            cmap="viridis", annot=True, fmt=".2f")
plt.title("Global SHAP Interaction Matrix")
plt.tight_layout()
plt.show()

# %%
r2 = skmetrics.r2_score(y_test,reg.predict(X_test))
print("The r2 on the train set: {:0.4f} and on the test set: {:0.4f}".format(skmetrics.r2_score(y_train,reg.predict(X_train)),r2))
#mcc = skmetrics.matthews_corrcoef(y_test,reg.predict(X_test))
#print("The MCC on the train set: {:0.4f} and on the test set: {:0.4f}".format(skmetrics.matthews_corrcoef(y_train,reg.predict(X_train)),mcc))
mse = skmetrics.mean_squared_error(y_test,reg.predict(X_test))
print("The mse on the test set: {:0.4f}".format(mse))
fig,ax=plt.subplots(1,1,dpi=300)
ax.loglog(np.exp(y_train),np.exp(reg.predict(X_train)),'b.',label='Training')
ax.loglog(np.exp(y_test),np.exp(reg.predict(X_test)),'ks',label='Testing')
ax.set_xlabel("Observed mob distance (m)")
ax.set_ylabel("Modeled mob distance (m)")
ax.loglog([1e1,1e4],[1e1,1e4],'k:',color="0.5")
# Out:
# The r2 on the train set: 0.7172 and on the test set: 0.4099
# The mse on the test set: 2.9192
# /tmp/ipykernel_907/1752818483.py:12: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k:" (-> color='k'). The keyword argument will take precedence.
#   ax.loglog([1e1,1e4],[1e1,1e4],'k:',color="0.5")

# %%
temp["41_42_43"]
temp["forest"] = temp["41_42_43"]
temp["urban"] = temp["22_23_24"]

# %%
temp["forest"]
# Out:
# watershed  Asset           dt                         site_no
# chicago    Clyde           2022-10-11 05:02:01-05:00  05535000    5.35
#                            2022-10-30 11:11:29-05:00  05535000    5.35
#            Caleb           2022-11-17 04:10:10-06:00  05535000    5.44
#            Cassidy         2022-09-15 23:01:51-05:00  05535000    5.35
#                            2022-09-16 17:17:14-05:00  05535000    5.35
#                                                                   ...
# socal      Periwinkle_1_0  2024-01-20 18:10:49-08:00  11048600    0.08
#            Periwinkle_1_1  2024-02-05 06:00:50-08:00  11048600    0.15
#                            2024-02-07 09:58:50-08:00  11048600    0.14
#                            2024-02-08 09:51:31-08:00  11048600    0.14
#                            2024-02-09 13:58:32-08:00  11048600    0.14
# Name: forest, Length: 1242, dtype: float64

# %%
print(temp.clip(lower=1e-7).reset_index(level=0)["Q_m3s"].min())
# Out:
# 1e-07

# %% [markdown]
# Now we're going to do some multi-model selection and test all combinations of 5 factors that look like they could be the most important.

# %% [markdown]
# These include every combination of interactions regardless of whether the factor was in the main effects. Takes about 20 minutes to run them all.

# %% [raw]
# # Define predictors
# predictors = ['Q_m3s', 'forest', 'sinuosity','schrub']
#
# # Generate all non-empty combinations of main effects
# main_effect_combos = list(chain.from_iterable(
#     combinations(predictors, r) for r in range(1, len(predictors) + 1)
# ))
#
# # Generate all combinations of pairwise interactions (from 10 possible pairs)
# interaction_pairs = list(combinations(predictors, 2))
# interaction_combos = list(chain.from_iterable(
#     combinations(interaction_pairs, r) for r in range(1, len(interaction_pairs) + 1)
# ))
#
# # Generate all formulas combining main effects and interaction terms
# formulas = set()
#
# # Main effects + interaction terms
# for main_effects in main_effect_combos:
#     main_str = ' + '.join([f'np.log({var})' for var in main_effects])
#     for interactions in interaction_combos:
#         interaction_str = ' + '.join([f'np.log({i[0]}):np.log({i[1]})' for i in interactions])
#         formula = f'np.log(len_m) ~ {main_str} + {interaction_str}'
#         formulas.add(formula)
#
# # Main effects only
# for main_effects in main_effect_combos:
#     main_str = ' + '.join([f'np.log({var})' for var in main_effects])
#     formula = f'np.log(len_m) ~ {main_str}'
#     formulas.add(formula)
#
# # Interaction terms only
# for interactions in interaction_combos:
#     interaction_str = ' + '.join([f'np.log({i[0]}):np.log({i[1]})' for i in interactions])
#     formula = f'np.log(len_m) ~ {interaction_str}'
#     formulas.add(formula)
#
# # Convert to sorted list and print summary
# formulas = sorted(formulas)
# print(f"Total unique formulas generated: {len(formulas)}")
# for f in formulas[:10]:
#     print(f)

# %% [markdown]
# Now these limit the formulas to just those whose interaction terms are included in the main effects

# %%
Rormulas = []
N=0
for less in ["urban","sinuosity","schrub","wetland","crops"]:
    
    # Define predictors
    predictors = ['Q_m3s', 'forest',less ] #, 'urban'] #,'sinuosity']
    
    # Generate all non-empty combinations of main effects
    main_effect_combos = list(chain.from_iterable(
        combinations(predictors, r) for r in range(1, len(predictors) + 1)
    ))
    
    # Generate formulas with interaction terms only among variables present in main effects
    rormulas = set()
    transforms=lambda x: "sqrt" if x == "forest" else "log"
    
    for main_effects in main_effect_combos:
        main_str = ' + '.join([f'np.{transforms(var)}({var})' for var in main_effects])
        base_formula = f'np.log(len_m) ~ {main_str}'
    
        # Add interaction terms only among variables in main_effects
        interaction_terms = list(combinations(main_effects, 2))
        for r in range(len(interaction_terms) + 1):
            for interaction_combo in combinations(interaction_terms, r):
                interaction_str = ' + '.join([f'np.{transforms(i[0])}({i[0]}):np.{transforms(i[1])}({i[1]})' for i in interaction_combo])
                if interaction_str:
                    full_formula = f'{base_formula} + {interaction_str}'
                else:
                    full_formula = base_formula
                rormulas.add(full_formula)
    
    # Convert to sorted list and print summary
    rormulas = sorted(rormulas)
    print(f"Total unique formulas generated: {len(rormulas)}")
    N+=len(rormulas)
    Rormulas += [rormulas]
print(f"{N} total formulas")
# Out:
# Total unique formulas generated: 17
# Total unique formulas generated: 17
# Total unique formulas generated: 17
# Total unique formulas generated: 17
# Total unique formulas generated: 17
# 85 total formulas

# %%
Rormulas
# Out:
# [['np.log(len_m) ~ np.log(Q_m3s)',
#   'np.log(len_m) ~ np.log(Q_m3s) + np.log(urban)',
#   'np.log(len_m) ~ np.log(Q_m3s) + np.log(urban) + np.log(Q_m3s):np.log(urban)',
#   'np.log(len_m) ~ np.log(Q_m3s) + np.sqrt(forest)',
#   'np.log(len_m) ~ np.log(Q_m3s) + np.sqrt(forest) + np.log(Q_m3s):np.sqrt(forest)',
#   'np.log(len_m) ~ np.log(Q_m3s) + np.sqrt(forest) + np.log(urban)',
#   'np.log(len_m) ~ np.log(Q_m3s) + np.sqrt(forest) + np.log(urban) + np.log(Q_m3s):np.log(urban)',
#   'np.log(len_m) ~ np.log(Q_m3s) + np.sqrt(forest) + np.log(urban) + np.log(Q_m3s):np.log(urban) + np.sqrt(forest):np.log(urban)',
#   'np.log(len_m) ~ np.log(Q_m3s) + np.sqrt(forest) + np.log(urban) + np.log(Q_m3s):np.sqrt(forest)',
#   'np.log(len_m) ~ np.log(Q_m3s) + np.sqrt(forest) + np.log(urban) + np.log(Q_m3s):np.sqrt(forest) + np.log(Q_m3s):np.log(urban)',
#   'np.log(len_m) ~ np.log(Q_m3s) + np.sqrt(forest) + np.log(urban) + np.log(Q_m3s):np.sqrt(forest) + np.log(Q_m3s):np.log(urban) + np.sqrt(forest):np.log(urban)',
#   'np.log(len_m) ~ np.log(Q_m3s) + np.sqrt(forest) + np.log(urban) + np.log(Q_m3s):np.sqrt(forest) + np.sqrt(forest):np.log(urban)',
#   'np.log(len_m) ~ np.log(Q_m3s) + np.sqrt(forest) + np.log(urban) + np.sqrt(forest):np.log(urban)',
#   'np.log(len_m) ~ np.log(urban)',
#   'np.log(len_m) ~ np.sqrt(forest)',
#   'np.log(len_m) ~ np.sqrt(forest) + np.log(urban)',
#   'np.log(len_m) ~ np.sqrt(forest) + np.log(urban) + np.sqrt(forest):np.log(urban)'],
#  ['np.log(len_m) ~ np.log(Q_m3s)',
#   'np.log(len_m) ~ np.log(Q_m3s) + np.log(sinuosity)',
#   'np.log(len_m) ~ np.log(Q_m3s) + np.log(sinuosity) + np.log(Q_m3s):np.log(sinuosity)',
#   'np.log(len_m) ~ np.log(Q_m3s) + np.sqrt(forest)',
#   'np.log(len_m) ~ np.log(Q_m3s) + np.sqrt(forest) + np.log(Q_m3s):np.sqrt(forest)',
#   'np.log(len_m) ~ np.log(Q_m3s) + np.sqrt(forest) + np.log(sinuosity)',
#   'np.log(len_m) ~ np.log(Q_m3s) + np.sqrt(forest) + np.log(sinuosity) + np.log(Q_m3s):np.log(sinuosity)',
#   'np.log(len_m) ~ np.log(Q_m3s) + np.sqrt(forest) + np.log(sinuosity) + np.log(Q_m3s):np.log(sinuosity) + np.sqrt(forest):np.log(sinuosity)',
#   'np.log(len_m) ~ np.log(Q_m3s) + np.sqrt(forest) + np.log(sinuosity) + np.log(Q_m3s):np.sqrt(forest)',
#   'np.log(len_m) ~ np.log(Q_m3s) + np.sqrt(forest) + np.log(sinuosity) + np.log(Q_m3s):np.sqrt(forest) + np.log(Q_m3s):np.log(sinuosity)',
#   'np.log(len_m) ~ np.log(Q_m3s) + np.sqrt(forest) + np.log(sinuosity) + np.log(Q_m3s):np.sqrt(forest) + np.log(Q_m3s):np.log(sinuosity) + np.sqrt(forest):np.log(sinuosity)',
#   'np.log(len_m) ~ np.log(Q_m3s) + np.sqrt(forest) + np.log(sinuosity) + np.log(Q_m3s):np.sqrt(forest) + np.sqrt(forest):np.log(sinuosity)',
#   'np.log(len_m) ~ np.log(Q_m3s) + np.sqrt(forest) + np.log(sinuosity) + np.sqrt(forest):np.log(sinuosity)',
#   'np.log(len_m) ~ np.log(sinuosity)',
#   'np.log(len_m) ~ np.sqrt(forest)',
#   'np.log(len_m) ~ np.sqrt(forest) + np.log(sinuosity)',
#   'np.log(len_m) ~ np.sqrt(forest) + np.log(sinuosity) + np.sqrt(forest):np.log(sinuosity)'],
#  ['np.log(len_m) ~ np.log(Q_m3s)',
#   'np.log(len_m) ~ np.log(Q_m3s) + np.log(schrub)',
#   'np.log(len_m) ~ np.log(Q_m3s) + np.log(schrub) + np.log(Q_m3s):np.log(schrub)',
#   'np.log(len_m) ~ np.log(Q_m3s) + np.sqrt(forest)',
#   'np.log(len_m) ~ np.log(Q_m3s) + np.sqrt(forest) + np.log(Q_m3s):np.sqrt(forest)',
#   'np.log(len_m) ~ np.log(Q_m3s) + np.sqrt(forest) + np.log(schrub)',
#   'np.log(len_m) ~ np.log(Q_m3s) + np.sqrt(forest) + np.log(schrub) + np.log(Q_m3s):np.log(schrub)',
#   'np.log(len_m) ~ np.log(Q_m3s) + np.sqrt(forest) + np.log(schrub) + np.log(Q_m3s):np.log(schrub) + np.sqrt(forest):np.log(schrub)',
#   'np.log(len_m) ~ np.log(Q_m3s) + np.sqrt(forest) + np.log(schrub) + np.log(Q_m3s):np.sqrt(forest)',
#   'np.log(len_m) ~ np.log(Q_m3s) + np.sqrt(forest) + np.log(schrub) + np.log(Q_m3s):np.sqrt(forest) + np.log(Q_m3s):np.log(schrub)',
#   'np.log(len_m) ~ np.log(Q_m3s) + np.sqrt(forest) + np.log(schrub) + np.log(Q_m3s):np.sqrt(forest) + np.log(Q_m3s):np.log(schrub) + np.sqrt(forest):np.log(schrub)',
#   'np.log(len_m) ~ np.log(Q_m3s) + np.sqrt(forest) + np.log(schrub) + np.log(Q_m3s):np.sqrt(forest) + np.sqrt(forest):np.log(schrub)',
#   'np.log(len_m) ~ np.log(Q_m3s) + np.sqrt(forest) + np.log(schrub) + np.sqrt(forest):np.log(schrub)',
#   'np.log(len_m) ~ np.log(schrub)',
#   'np.log(len_m) ~ np.sqrt(forest)',
#   'np.log(len_m) ~ np.sqrt(forest) + np.log(schrub)',
#   'np.log(len_m) ~ np.sqrt(forest) + np.log(schrub) + np.sqrt(forest):np.log(schrub)'],
#  ['np.log(len_m) ~ np.log(Q_m3s)',
#   'np.log(len_m) ~ np.log(Q_m3s) + np.log(wetland)',
#   'np.log(len_m) ~ np.log(Q_m3s) + np.log(wetland) + np.log(Q_m3s):np.log(wetland)',
#   'np.log(len_m) ~ np.log(Q_m3s) + np.sqrt(forest)',
#   'np.log(len_m) ~ np.log(Q_m3s) + np.sqrt(forest) + np.log(Q_m3s):np.sqrt(forest)',
#   'np.log(len_m) ~ np.log(Q_m3s) + np.sqrt(forest) + np.log(wetland)',
#   'np.log(len_m) ~ np.log(Q_m3s) + np.sqrt(forest) + np.log(wetland) + np.log(Q_m3s):np.log(wetland)',
#   'np.log(len_m) ~ np.log(Q_m3s) + np.sqrt(forest) + np.log(wetland) + np.log(Q_m3s):np.log(wetland) + np.sqrt(forest):np.log(wetland)',
#   'np.log(len_m) ~ np.log(Q_m3s) + np.sqrt(forest) + np.log(wetland) + np.log(Q_m3s):np.sqrt(forest)',
#   'np.log(len_m) ~ np.log(Q_m3s) + np.sqrt(forest) + np.log(wetland) + np.log(Q_m3s):np.sqrt(forest) + np.log(Q_m3s):np.log(wetland)',
#   'np.log(len_m) ~ np.log(Q_m3s) + np.sqrt(forest) + np.log(wetland) + np.log(Q_m3s):np.sqrt(forest) + np.log(Q_m3s):np.log(wetland) + np.sqrt(forest):np.log(wetland)',
#   'np.log(len_m) ~ np.log(Q_m3s) + np.sqrt(forest) + np.log(wetland) + np.log(Q_m3s):np.sqrt(forest) + np.sqrt(forest):np.log(wetland)',
#   'np.log(len_m) ~ np.log(Q_m3s) + np.sqrt(forest) + np.log(wetland) + np.sqrt(forest):np.log(wetland)',
#   'np.log(len_m) ~ np.log(wetland)',
#   'np.log(len_m) ~ np.sqrt(forest)',
#   'np.log(len_m) ~ np.sqrt(forest) + np.log(wetland)',
#   'np.log(len_m) ~ np.sqrt(forest) + np.log(wetland) + np.sqrt(forest):np.log(wetland)'],
#  ['np.log(len_m) ~ np.log(Q_m3s)',
#   'np.log(len_m) ~ np.log(Q_m3s) + np.log(crops)',
#   'np.log(len_m) ~ np.log(Q_m3s) + np.log(crops) + np.log(Q_m3s):np.log(crops)',
#   'np.log(len_m) ~ np.log(Q_m3s) + np.sqrt(forest)',
#   'np.log(len_m) ~ np.log(Q_m3s) + np.sqrt(forest) + np.log(Q_m3s):np.sqrt(forest)',
#   'np.log(len_m) ~ np.log(Q_m3s) + np.sqrt(forest) + np.log(crops)',
#   'np.log(len_m) ~ np.log(Q_m3s) + np.sqrt(forest) + np.log(crops) + np.log(Q_m3s):np.log(crops)',
#   'np.log(len_m) ~ np.log(Q_m3s) + np.sqrt(forest) + np.log(crops) + np.log(Q_m3s):np.log(crops) + np.sqrt(forest):np.log(crops)',
#   'np.log(len_m) ~ np.log(Q_m3s) + np.sqrt(forest) + np.log(crops) + np.log(Q_m3s):np.sqrt(forest)',
#   'np.log(len_m) ~ np.log(Q_m3s) + np.sqrt(forest) + np.log(crops) + np.log(Q_m3s):np.sqrt(forest) + np.log(Q_m3s):np.log(crops)',
#   'np.log(len_m) ~ np.log(Q_m3s) + np.sqrt(forest) + np.log(crops) + np.log(Q_m3s):np.sqrt(forest) + np.log(Q_m3s):np.log(crops) + np.sqrt(forest):np.log(crops)',
#   'np.log(len_m) ~ np.log(Q_m3s) + np.sqrt(forest) + np.log(crops) + np.log(Q_m3s):np.sqrt(forest) + np.sqrt(forest):np.log(crops)',
#   'np.log(len_m) ~ np.log(Q_m3s) + np.sqrt(forest) + np.log(crops) + np.sqrt(forest):np.log(crops)',
#   'np.log(len_m) ~ np.log(crops)',
#   'np.log(len_m) ~ np.sqrt(forest)',
#   'np.log(len_m) ~ np.sqrt(forest) + np.log(crops)',
#   'np.log(len_m) ~ np.sqrt(forest) + np.log(crops) + np.sqrt(forest):np.log(crops)']]

# %%
pd.set_option("display.precision", 2)
pd.set_option("display.width", 280)
pd.set_option("display.max_colwidth",220)

# %% [markdown]
# #### We now assess model peformance for the full model.  We fit a Robust Linear Model to each combination of predictors and interactions using the two primary predictors (Q and Forest) plus each of the 5 potential tertiary predictors.  We then select the tertiary predictor resulting in the most performant models (r2), and select the specific model based on Jaques-Bera statistic and BIC/AIC.

# %%
temp = lcdistclean.set_index("site_no",append=True).drop(columns=['Point_ID','level_0'])
temp = temp["len_m Q_m3s 41_42_43 22_23_24 sinuosity 52 95 82".split()]
temp = temp.rename(columns={"41_42_43":"forest","22_23_24":"urban","52":"schrub","95":"wetland","82":"crops"})
temp["forest"] *= 0.01
temp["urban"] *= 0.01
temp["schrub"] *= 0.01
temp = temp.dropna()
full = temp.clip(lower=1e-7)
miami = full.xs("miami",level=0)
# Make clean  - less Miami and short events
#clean = temp.drop("miami",level=0)
full = full[full["len_m"] > 8]
AICs=[]
BICs=[]
r2adjs=[]
jbs=[]
rormulas = [rormula 
       for formulas in Rormulas 
       for rormula in formulas]  # 

for formula in rormulas:
    robust_model = smf.rlm(formula,data=full,missing='drop',M=sm.robust.norms.HuberT())
    #glm_model = smf.glm(formula,data=clean,missing='drop',family=sm.families.Gamma(link=sm.families.links.log()))
    robust_model = robust_model.fit()
    #glm_model = glm_model.fit()
    # wls flow
    #ols_model = smf.ols(formula,data=clean,missing='drop').fit()
    #wls_model = smf.wls(formula,data=clean,weights=1./(np.abs(ols_model.resid) + 1e-6),missing='drop').fit()
    
    
    # Assuming `robust_model` is your fitted RLM model
    # and `y` is your dependent variable (e.g., df['log_len_m'])
    
    # Number of observations and parameters
    n = robust_model.nobs
    k = robust_model.df_model + 1  # includes intercept
    #n = glm_model.nobs
    #k = glm_model.df_model + 1
    #n = wls_model.nobs
    #k = wls_model.df_model + 1
    
    # Residual sum of squares
    rss = np.sum(robust_model.resid ** 2)
    #rss = np.sum(glm_model.resid_response ** 2)
    #rss = np.sum(wls_model.resid ** 2)
    
    # AIC and BIC
    aic = n * np.log(rss / n) + 2 * k
    bic = n * np.log(rss / n) + k * np.log(n)
    
    # Adjusted R-squared
    y = np.log(full['len_m'])
    y_mean = np.mean(y)
    tss = np.sum((y - y_mean) ** 2)
    r2 = 1 - rss / tss
    r2_adj = 1 - (1 - r2) * (n - 1) / (n - k)
    
    # Jarque-Bera test
    jb_stat, jb_pvalue,_,_ = sm.stats.stattools.jarque_bera(robust_model.resid)
    #jb_stat, jb_pvalue,_,_ = sm.stats.stattools.jarque_bera(glm_model.resid_response)
    #jb_stat, jb_pvalue,_,_ = sm.stats.stattools.jarque_bera(wls_model.resid)
    
    # Print results
    #print(f"AIC: {aic:.2f}")
    #print(f"BIC: {bic:.2f}")
    #print(f"Adjusted R-squared: {r2_adj:.4f}")
    #print(f"Jarque-Bera Statistic: {jb_stat:.4f}, p-value: {jb_pvalue:.4g}")

    
    #print(mod.summary())
    AICs.append(aic)
    BICs.append(bic)
    r2adjs.append(r2_adj)
    jbs.append(jb_pvalue)
regress_table = pd.DataFrame(index=range(len(rormulas)),data={"Formula":rormulas,"AIC":AICs,"BIC":BICs,"r2_adj":r2adjs,"Prob(Jarque-Bera)":jbs})

# %%
regress_table["formula"] = regress_table["Formula"].apply(lambda x: x.replace("np.log",""))
display(regress_table.drop(columns="Formula").sort_values("Prob(Jarque-Bera)",ascending=False).head(10))
display(regress_table.drop(columns="Formula").sort_values("r2_adj",ascending=False).head(10))
display(regress_table.drop(columns="Formula").sort_values("BIC",ascending=True))
# Out:
#         AIC      BIC  r2_adj  Prob(Jarque-Bera)                                                                                                                 formula
# 78  1187.71  1221.90    0.24           5.34e-05     (len_m) ~ (Q_m3s) + np.sqrt(forest) + (crops) + (Q_m3s):np.sqrt(forest) + (Q_m3s):(crops) + np.sqrt(forest):(crops)
# 79  1194.69  1224.00    0.23           1.77e-05                       (len_m) ~ (Q_m3s) + np.sqrt(forest) + (crops) + (Q_m3s):np.sqrt(forest) + np.sqrt(forest):(crops)
# 75  1198.23  1227.54    0.23           1.56e-05                               (len_m) ~ (Q_m3s) + np.sqrt(forest) + (crops) + (Q_m3s):(crops) + np.sqrt(forest):(crops)
# 45  1174.13  1203.44    0.25           1.05e-05                     (len_m) ~ (Q_m3s) + np.sqrt(forest) + (schrub) + (Q_m3s):np.sqrt(forest) + np.sqrt(forest):(schrub)
# 44  1175.90  1210.09    0.25           8.44e-06  (len_m) ~ (Q_m3s) + np.sqrt(forest) + (schrub) + (Q_m3s):np.sqrt(forest) + (Q_m3s):(schrub) + np.sqrt(forest):(schrub)
# 74  1196.81  1221.23    0.23           4.97e-06                                                         (len_m) ~ (Q_m3s) + np.sqrt(forest) + (crops) + (Q_m3s):(crops)
# 77  1188.46  1217.77    0.23           4.35e-06                               (len_m) ~ (Q_m3s) + np.sqrt(forest) + (crops) + (Q_m3s):np.sqrt(forest) + (Q_m3s):(crops)
# 11  1208.43  1237.74    0.22           2.21e-06                       (len_m) ~ (Q_m3s) + np.sqrt(forest) + (urban) + (Q_m3s):np.sqrt(forest) + np.sqrt(forest):(urban)
# 62  1204.95  1234.26    0.22           1.87e-06                   (len_m) ~ (Q_m3s) + np.sqrt(forest) + (wetland) + (Q_m3s):np.sqrt(forest) + np.sqrt(forest):(wetland)
# 2   1244.96  1264.50    0.19           1.25e-06                                                                           (len_m) ~ (Q_m3s) + (urban) + (Q_m3s):(urban)
#         AIC      BIC  r2_adj  Prob(Jarque-Bera)                                                                                                                    formula
# 45  1174.13  1203.44    0.25           1.05e-05                        (len_m) ~ (Q_m3s) + np.sqrt(forest) + (schrub) + (Q_m3s):np.sqrt(forest) + np.sqrt(forest):(schrub)
# 44  1175.90  1210.09    0.25           8.44e-06     (len_m) ~ (Q_m3s) + np.sqrt(forest) + (schrub) + (Q_m3s):np.sqrt(forest) + (Q_m3s):(schrub) + np.sqrt(forest):(schrub)
# 42  1182.01  1206.44    0.24           2.31e-07                                                   (len_m) ~ (Q_m3s) + np.sqrt(forest) + (schrub) + (Q_m3s):np.sqrt(forest)
# 43  1183.08  1212.38    0.24           2.08e-07                                (len_m) ~ (Q_m3s) + np.sqrt(forest) + (schrub) + (Q_m3s):np.sqrt(forest) + (Q_m3s):(schrub)
# 78  1187.71  1221.90    0.24           5.34e-05        (len_m) ~ (Q_m3s) + np.sqrt(forest) + (crops) + (Q_m3s):np.sqrt(forest) + (Q_m3s):(crops) + np.sqrt(forest):(crops)
# 77  1188.46  1217.77    0.23           4.35e-06                                  (len_m) ~ (Q_m3s) + np.sqrt(forest) + (crops) + (Q_m3s):np.sqrt(forest) + (Q_m3s):(crops)
# 41  1188.67  1217.98    0.23           7.65e-07                               (len_m) ~ (Q_m3s) + np.sqrt(forest) + (schrub) + (Q_m3s):(schrub) + np.sqrt(forest):(schrub)
# 61  1191.76  1225.95    0.23           9.38e-08  (len_m) ~ (Q_m3s) + np.sqrt(forest) + (wetland) + (Q_m3s):np.sqrt(forest) + (Q_m3s):(wetland) + np.sqrt(forest):(wetland)
# 40  1192.52  1216.95    0.23           1.70e-07                                                          (len_m) ~ (Q_m3s) + np.sqrt(forest) + (schrub) + (Q_m3s):(schrub)
# 79  1194.69  1224.00    0.23           1.77e-05                          (len_m) ~ (Q_m3s) + np.sqrt(forest) + (crops) + (Q_m3s):np.sqrt(forest) + np.sqrt(forest):(crops)
#         AIC      BIC    r2_adj  Prob(Jarque-Bera)                                                                                                                 formula
# 45  1174.13  1203.44  2.46e-01           1.05e-05                     (len_m) ~ (Q_m3s) + np.sqrt(forest) + (schrub) + (Q_m3s):np.sqrt(forest) + np.sqrt(forest):(schrub)
# 42  1182.01  1206.44  2.39e-01           2.31e-07                                                (len_m) ~ (Q_m3s) + np.sqrt(forest) + (schrub) + (Q_m3s):np.sqrt(forest)
# 44  1175.90  1210.09  2.45e-01           8.44e-06  (len_m) ~ (Q_m3s) + np.sqrt(forest) + (schrub) + (Q_m3s):np.sqrt(forest) + (Q_m3s):(schrub) + np.sqrt(forest):(schrub)
# 43  1183.08  1212.38  2.39e-01           2.08e-07                             (len_m) ~ (Q_m3s) + np.sqrt(forest) + (schrub) + (Q_m3s):np.sqrt(forest) + (Q_m3s):(schrub)
# 40  1192.52  1216.95  2.30e-01           1.70e-07                                                       (len_m) ~ (Q_m3s) + np.sqrt(forest) + (schrub) + (Q_m3s):(schrub)
# ..      ...      ...       ...                ...                                                                                                                     ...
# 13  1362.06  1371.83  8.19e-02           5.03e-12                                                                                                       (len_m) ~ (urban)
# 81  1392.38  1402.15  5.29e-02           1.09e-11                                                                                                       (len_m) ~ (crops)
# 64  1425.08  1434.85  2.07e-02           7.59e-17                                                                                                     (len_m) ~ (wetland)
# 47  1428.72  1438.49  1.70e-02           1.66e-16                                                                                                      (len_m) ~ (schrub)
# 30  1440.19  1449.96  5.41e-03           1.91e-17                                                                                                   (len_m) ~ (sinuosity)
#
# [85 rows x 5 columns]

# %% [markdown]
# Models containing shrub cover are slightly more performant.

# %%
temp = lcdistclean.set_index("site_no",append=True).drop(columns=['Point_ID','level_0'])
temp = temp["len_m Q_m3s 41_42_43 22_23_24 sinuosity 52 95 82".split()]
temp = temp.rename(columns={"41_42_43":"forest","22_23_24":"urban","52":"schrub","95":"wetland","82":"crops"})
temp["forest"] *= 0.01
temp["urban"] *= 0.01
temp["schrub"] *= 0.01
temp = temp.dropna()
full = temp.clip(lower=1e-7)
miami = full.xs("miami",level=0)
# Make clean  - less Miami and short events
#clean = temp.drop("miami",level=0)
full = full[full["len_m"] > 8]
AICs=[]
BICs=[]
r2adjs=[]
jbs=[]
rormulas = Rormulas[2] # The full model finds that shrub (?) is the most performant tertiary factor

for formula in rormulas:
    robust_model = smf.rlm(formula,data=full,missing='drop',M=sm.robust.norms.HuberT())
    #glm_model = smf.glm(formula,data=clean,missing='drop',family=sm.families.Gamma(link=sm.families.links.log()))
    robust_model = robust_model.fit()
    #glm_model = glm_model.fit()
    # wls flow
    #ols_model = smf.ols(formula,data=clean,missing='drop').fit()
    #wls_model = smf.wls(formula,data=clean,weights=1./(np.abs(ols_model.resid) + 1e-6),missing='drop').fit()
    
    
    # Assuming `robust_model` is your fitted RLM model
    # and `y` is your dependent variable (e.g., df['log_len_m'])
    
    # Number of observations and parameters
    n = robust_model.nobs
    k = robust_model.df_model + 1  # includes intercept
    #n = glm_model.nobs
    #k = glm_model.df_model + 1
    #n = wls_model.nobs
    #k = wls_model.df_model + 1
    
    # Residual sum of squares
    rss = np.sum(robust_model.resid ** 2)
    #rss = np.sum(glm_model.resid_response ** 2)
    #rss = np.sum(wls_model.resid ** 2)
    
    # AIC and BIC
    aic = n * np.log(rss / n) + 2 * k
    bic = n * np.log(rss / n) + k * np.log(n)
    
    # Adjusted R-squared
    y = np.log(full['len_m'])
    y_mean = np.mean(y)
    tss = np.sum((y - y_mean) ** 2)
    r2 = 1 - rss / tss
    r2_adj = 1 - (1 - r2) * (n - 1) / (n - k)
    
    # Jarque-Bera test
    jb_stat, jb_pvalue,_,_ = sm.stats.stattools.jarque_bera(robust_model.resid)
    #jb_stat, jb_pvalue,_,_ = sm.stats.stattools.jarque_bera(glm_model.resid_response)
    #jb_stat, jb_pvalue,_,_ = sm.stats.stattools.jarque_bera(wls_model.resid)
    
    # Print results
    #print(f"AIC: {aic:.2f}")
    #print(f"BIC: {bic:.2f}")
    #print(f"Adjusted R-squared: {r2_adj:.4f}")
    #print(f"Jarque-Bera Statistic: {jb_stat:.4f}, p-value: {jb_pvalue:.4g}")

    
    #print(mod.summary())
    AICs.append(aic)
    BICs.append(bic)
    r2adjs.append(r2_adj)
    jbs.append(jb_pvalue)
regress_table = pd.DataFrame(index=range(len(rormulas)),data={"Formula":rormulas,"AIC":AICs,"BIC":BICs,"r2_adj":r2adjs,"Prob(Jarque-Bera)":jbs})

# %%
regress_table["formula"] = regress_table["Formula"].apply(lambda x: x.replace("np.log",""))
display(regress_table.drop(columns="Formula").sort_values("Prob(Jarque-Bera)",ascending=False).head(10))
display(regress_table.drop(columns="Formula").sort_values("BIC",ascending=True))
# Out:
#         AIC      BIC  r2_adj  Prob(Jarque-Bera)                                                                                                                 formula
# 11  1174.13  1203.44    0.25           1.05e-05                     (len_m) ~ (Q_m3s) + np.sqrt(forest) + (schrub) + (Q_m3s):np.sqrt(forest) + np.sqrt(forest):(schrub)
# 10  1175.90  1210.09    0.25           8.44e-06  (len_m) ~ (Q_m3s) + np.sqrt(forest) + (schrub) + (Q_m3s):np.sqrt(forest) + (Q_m3s):(schrub) + np.sqrt(forest):(schrub)
# 7   1188.67  1217.98    0.23           7.65e-07                            (len_m) ~ (Q_m3s) + np.sqrt(forest) + (schrub) + (Q_m3s):(schrub) + np.sqrt(forest):(schrub)
# 12  1196.93  1221.35    0.23           3.02e-07                                               (len_m) ~ (Q_m3s) + np.sqrt(forest) + (schrub) + np.sqrt(forest):(schrub)
# 8   1182.01  1206.44    0.24           2.31e-07                                                (len_m) ~ (Q_m3s) + np.sqrt(forest) + (schrub) + (Q_m3s):np.sqrt(forest)
# 9   1183.08  1212.38    0.24           2.08e-07                             (len_m) ~ (Q_m3s) + np.sqrt(forest) + (schrub) + (Q_m3s):np.sqrt(forest) + (Q_m3s):(schrub)
# 6   1192.52  1216.95    0.23           1.70e-07                                                       (len_m) ~ (Q_m3s) + np.sqrt(forest) + (schrub) + (Q_m3s):(schrub)
# 4   1218.00  1237.54    0.21           9.48e-08                                                           (len_m) ~ (Q_m3s) + np.sqrt(forest) + (Q_m3s):np.sqrt(forest)
# 5   1201.63  1221.17    0.22           1.91e-08                                                                          (len_m) ~ (Q_m3s) + np.sqrt(forest) + (schrub)
# 16  1269.37  1288.91    0.17           4.34e-09                                                         (len_m) ~ np.sqrt(forest) + (schrub) + np.sqrt(forest):(schrub)
#         AIC      BIC  r2_adj  Prob(Jarque-Bera)                                                                                                                 formula
# 11  1174.13  1203.44    0.25           1.05e-05                     (len_m) ~ (Q_m3s) + np.sqrt(forest) + (schrub) + (Q_m3s):np.sqrt(forest) + np.sqrt(forest):(schrub)
# 8   1182.01  1206.44    0.24           2.31e-07                                                (len_m) ~ (Q_m3s) + np.sqrt(forest) + (schrub) + (Q_m3s):np.sqrt(forest)
# 10  1175.90  1210.09    0.25           8.44e-06  (len_m) ~ (Q_m3s) + np.sqrt(forest) + (schrub) + (Q_m3s):np.sqrt(forest) + (Q_m3s):(schrub) + np.sqrt(forest):(schrub)
# 9   1183.08  1212.38    0.24           2.08e-07                             (len_m) ~ (Q_m3s) + np.sqrt(forest) + (schrub) + (Q_m3s):np.sqrt(forest) + (Q_m3s):(schrub)
# 6   1192.52  1216.95    0.23           1.70e-07                                                       (len_m) ~ (Q_m3s) + np.sqrt(forest) + (schrub) + (Q_m3s):(schrub)
# 7   1188.67  1217.98    0.23           7.65e-07                            (len_m) ~ (Q_m3s) + np.sqrt(forest) + (schrub) + (Q_m3s):(schrub) + np.sqrt(forest):(schrub)
# 5   1201.63  1221.17    0.22           1.91e-08                                                                          (len_m) ~ (Q_m3s) + np.sqrt(forest) + (schrub)
# 12  1196.93  1221.35    0.23           3.02e-07                                               (len_m) ~ (Q_m3s) + np.sqrt(forest) + (schrub) + np.sqrt(forest):(schrub)
# 4   1218.00  1237.54    0.21           9.48e-08                                                           (len_m) ~ (Q_m3s) + np.sqrt(forest) + (Q_m3s):np.sqrt(forest)
# 3   1237.00  1251.65    0.19           2.30e-09                                                                                     (len_m) ~ (Q_m3s) + np.sqrt(forest)
# 15  1270.89  1285.54    0.16           6.00e-10                                                                                    (len_m) ~ np.sqrt(forest) + (schrub)
# 16  1269.37  1288.91    0.17           4.34e-09                                                         (len_m) ~ np.sqrt(forest) + (schrub) + np.sqrt(forest):(schrub)
# 2   1321.43  1340.97    0.12           1.97e-10                                                                         (len_m) ~ (Q_m3s) + (schrub) + (Q_m3s):(schrub)
# 14  1339.05  1348.82    0.10           2.32e-13                                                                                               (len_m) ~ np.sqrt(forest)
# 0   1339.78  1349.54    0.10           4.04e-12                                                                                                       (len_m) ~ (Q_m3s)
# 1   1337.93  1352.58    0.11           6.70e-12                                                                                            (len_m) ~ (Q_m3s) + (schrub)
# 13  1428.72  1438.49    0.02           1.66e-16                                                                                                      (len_m) ~ (schrub)

# %% [markdown]
# Both Jaques-Bera and BIC select formula 11 as the "best" model for the full data.

# %%
best_idx = 11
formula = rormulas[best_idx]
print(formula)
print("AIC: {:0.1f}, BIC: {:0.1f}, r2adj: {:0.3f}, P(jb): {:0.3f}".format(AICs[best_idx], BICs[best_idx], r2adjs[best_idx], jbs[best_idx]))

mod = smf.rlm(formula,data=full,missing='drop',M=sm.robust.norms.HuberT())
#glm_model = smf.glm(formula,data=clean,missing='drop',family=sm.families.Gamma(link=sm.families.links.log()))
#ols_model = smf.ols(formula,data=clean,missing='drop').fit()
#wls_model = smf.wls(formula,data=clean,missing='drop',weights=1./(np.abs(ols_model.resid) + 1e-6))


# Create design matrices
y, X = dmatrices(formula, data=full, return_type='dataframe')
print(X.shape)
print("VIFs: ")
print([(X.iloc[:,i].name,vif(X,i)) for i in range(X.shape[1]) ])

mod = mod.fit()
mod.resid.hist()
print(mod.summary())

#glm_model = glm_model.fit()
#wls_model = wls_model.fit()
#print(dir(glm_model))
#wls_model.resid.hist().plot()
# Out:
# np.log(len_m) ~ np.log(Q_m3s) + np.sqrt(forest) + np.log(schrub) + np.log(Q_m3s):np.sqrt(forest) + np.sqrt(forest):np.log(schrub)
# AIC: 1174.1, BIC: 1203.4, r2adj: 0.246, P(jb): 0.000
# (977, 6)
# VIFs:
# [('Intercept', 13.830430988866), ('np.log(Q_m3s)', 2.877919343503213), ('np.sqrt(forest)', 4.972843970939066), ('np.log(schrub)', 2.9368671888118487), ('np.log(Q_m3s):np.sqrt(forest)', 2.94325493202422), ('np.sqrt(forest):np.log(schrub)', 5.076790179385703)]
#                     Robust linear Model Regression Results
# ==============================================================================
# Dep. Variable:          np.log(len_m)   No. Observations:                  977
# Model:                            RLM   Df Residuals:                      971
# Method:                          IRLS   Df Model:                            5
# Norm:                          HuberT
# Scale Est.:                       mad
# Cov Type:                          H1
# Date:                Fri, 17 Jul 2026
# Time:                        15:17:41
# No. Iterations:                    16
# ==================================================================================================
#                                      coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                          7.2694      0.228     31.828      0.000       6.822       7.717
# np.log(Q_m3s)                      0.0540      0.044      1.230      0.219      -0.032       0.140
# np.sqrt(forest)                   -7.0731      0.838     -8.442      0.000      -8.715      -5.431
# np.log(schrub)                     0.1392      0.020      6.975      0.000       0.100       0.178
# np.log(Q_m3s):np.sqrt(forest)      0.8404      0.151      5.581      0.000       0.545       1.136
# np.sqrt(forest):np.log(schrub)    -0.3601      0.099     -3.646      0.000      -0.554      -0.167
# ==================================================================================================
#
# If the model instance has been used for another fit with different fit parameters, then the fit options might not be the correct ones anymore .

# %%
mod.wald_test("np.log(Q_m3s) = 0")
# Out:
# /home/shan/.pyenv/versions/3.11.9/lib/python3.11/site-packages/statsmodels/base/model.py:1912: FutureWarning: The behavior of wald_test will change after 0.14 to returning scalar test statistic values. To get the future behavior now, set scalar to True. To silence this message while retaining the legacy behavior, set scalar to False.
#   warnings.warn(
# <class 'statsmodels.stats.contrast.ContrastResults'>
# <Wald test (chi2): statistic=[[1.51356093]], p-value=0.21859652320634326, df_denom=1>

# %%
fig = sm.graphics.plot_partregress_grid(mod)
fig.tight_layout(pad=0.5)
fig.set_size_inches((12,8))

# %%
# Residuals from robust regression
#residuals = glm_model.resid_response
#residuals = wls_model.resid
residuals = mod.resid

# Candidate distributions
candidates = [stats.norm, stats.t, stats.laplace, stats.cauchy, stats.skewnorm,stats.lognorm]

# Fit and test each distribution
for dist in candidates:
    params = dist.fit(residuals)
    ks_stat, ks_pvalue = stats.kstest(residuals, dist.name, args=params)
    print(f"Distribution: {dist.name}")
    print(f"Parameters: {params}")
    print(f"KS Statistic: {ks_stat:.4f}, p-value: {ks_pvalue:.4g}\n")
# Out:
# Distribution: norm
# Parameters: (-0.013283816098516216, 1.8125173448208465)
# KS Statistic: 0.0472, p-value: 0.02469
#
# Distribution: t
# Parameters: (45520582082.33789, -0.013282050621573487, 1.8125181074030707)
# KS Statistic: 0.0472, p-value: 0.02469
#
# Distribution: laplace
# Parameters: (0.03173739417975785, 1.5258200865039468)
# KS Statistic: 0.0730, p-value: 5.675e-05
#
# Distribution: cauchy
# Parameters: (0.0390492914711351, 1.2598686066425686)
# KS Statistic: 0.1052, p-value: 7.242e-10
#
# Distribution: skewnorm
# Parameters: (-0.5674399885085124, 0.7634266698125327, 1.9719288063780127)
# KS Statistic: 0.0463, p-value: 0.02938
#
# Distribution: lognorm
# Parameters: (0.011591031826453754, -156.02509475360955, 156.00901507989977)
# KS Statistic: 0.0475, p-value: 0.02372
# /home/shan/.pyenv/versions/3.11.9/lib/python3.11/site-packages/scipy/stats/_continuous_distns.py:6547: RuntimeWarning: invalid value encountered in log
#   lndata = np.log(data - loc)

# %%
def get_color(uniques,cmap="tab20b"):
    
    cm=mpl.colormaps[cmap]
    uniqdict=dict((unique,cm(float(j)/len(uniques))) for unique,j in zip(uniques,range(len(uniques))))
    return uniqdict

def get_marker(uniques):
    markers=["o","v","^","s","p","D","*"]
    uniqdict=dict((unique,markers[j]) for unique,j in zip(uniques,range(len(uniques))))
    return uniqdict

dist_cutoff = 8

temp = lcdistclean.set_index("site_no",append=True).drop(columns=['Point_ID','level_0'])
temp = temp["len_m Q_m3s 41_42_43 22_23_24 sinuosity 52 95 82".split()]
temp = temp.rename(columns={"41_42_43":"forest","22_23_24":"urban","52":"schrub","95":"wetland","82":"crops"})
temp = temp.dropna()
temp["forest"] *= 0.01
temp["urban"] *= 0.01
temp["schrub"] *= 0.01
full = temp.clip(lower=1e-7)
#miami = temp.xs("miami",level=0)
# Make clean  - less Miami and short events
#clean = temp.drop("miami",level=0)
lows = full[full["len_m"] <= dist_cutoff]
full = full[full["len_m"] > dist_cutoff]

wseds = ['sfbay', 'socal', 'chicago','don', 'anacostia',  'ipswich', 'miami']

color_dict=get_color(wseds)
marker_dict=get_marker(wseds)
print(color_dict)
fig,axs=plt.subplots(1,1,dpi=300,sharey="row",figsize=(5,4),constrained_layout=True) 
axs=[axs]
for j,ax in enumerate(axs):

    def get_plabel(x):
        return ws_names[x]
    for site in wseds:
        if site == "miami":
            #continue
            pass
        dist = full.xs(site,level=0)

        print(get_plabel(site))
        dist.plot(ax=ax,x="Q_m3s",y="len_m",marker=marker_dict[site],c=color_dict[site],mec='k',ms=5,mew=0.15,ls="none",logx=False,logy=False,label=get_plabel(site))
        
    (lo,hi)=ax.get_xlim()
    lo,hi = 5e-5,5e3
    X=np.log(np.linspace(lo,hi,5))
    (yo,yi)=ax.get_ylim()
    yo,yi = 5e0,5e4    
    if j==1:
        miami.plot(ax=ax,x="Q_m3s",y="len_m",marker='x',c=color_dict["miami"],ls="none",logx=False,logy=False,ms=5,label="Miami")
        ax.get_legend().remove()
        for site,dist in lows.groupby(level=0):
            dist.plot(ax=ax,x="Q_m3s",y="len_m",marker='x',c=color_dict[site],ls="none",logx=False,logy=False,ms=5,legend=False)
    else:
        ax.get_legend().remove()
        (handles,labels) = ax.get_legend_handles_labels()

        qs_1 = full["forest"].quantile([0.05,0.5,0.95]).clip(lower=1e-9)
        qs_2 = full["schrub"].quantile([0.5])
        ps = ["{:0.0f}% forest".format(100.*q) for q in qs_1]
        lss = [":","--","-"]
        lcs = ["0.5","0.5","k"]
        print(qs_1)
        print(qs_2)
        for k,q in enumerate(qs_1):
            Xq = np.stack((X,(q**.5)*np.ones_like(X),np.log(qs_2.values)*np.ones_like(X),(q**.5)*np.log(qs_2.values)*np.ones_like(X)))
            #print(Xq)
            if len(mod.params) > 2:
                
                pred = mod.params[0]+mod.params[1]*Xq[0,:]+mod.params[2]*Xq[1,:]+mod.params[3]*Xq[2,:]+mod.params[4]*Xq[3,:]
            else:
                pred = mod.params[0]+mod.params[1]*Xq[0,:]
            print(np.exp(pred))
            
            ax.plot(np.exp(X),np.exp(pred),ls=lss[k],color=lcs[k],label=ps[k])
    
    ax.set_xlim((lo,hi))
    ax.set_ylim((yo,yi))
    ax.set_xscale('log')
    ax.set_yscale('log')
    ax.set_ylabel("Mobilization distance (m)")
    ax.set_xlabel("Discharge ($m^3\ s^{-1}$)")
    #ax.text(0.025,0.95,"ab"[j]+")",transform=ax.transAxes)

fig.subplots_adjust(wspace=0.05)
legend1 = axs[0].legend(handles,labels,bbox_to_anchor=[0.05,-0.30,0.3,0.15],ncol=3,loc=2)
axs[0].add_artist(legend1)

lines = [mpl.lines.Line2D([],[],color=lc,ls=ls,label=p) for p,ls,lc in zip(ps,lss,lcs)]
legend2 = axs[0].legend(lines,ps,bbox_to_anchor=[0.05,0.85,0.4,0.1],loc=2,fontsize=8)
axs[0].add_artist(legend2)
# Out:
# {'sfbay': (0.2235294117647059, 0.23137254901960785, 0.4745098039215686, 1.0), 'socal': (0.4196078431372549, 0.43137254901960786, 0.8117647058823529, 1.0), 'chicago': (0.5490196078431373, 0.6352941176470588, 0.3215686274509804, 1.0), 'don': (0.5490196078431373, 0.42745098039215684, 0.19215686274509805, 1.0), 'anacostia': (0.9058823529411765, 0.796078431372549, 0.5803921568627451, 1.0), 'ipswich': (0.8392156862745098, 0.3803921568627451, 0.4196078431372549, 1.0), 'miami': (0.6470588235294118, 0.3176470588235294, 0.5803921568627451, 1.0)}
# Walnut
# S.California
# N.Chicago
# Don
# Anacostia
# Ipswich
# Miami
# 0.05    1.00e-07
# 0.50    9.57e-02
# 0.95    2.52e-01
# Name: forest, dtype: float64
# 0.5    3.10e-03
# Name: schrub, dtype: float64
# [ 374.96256524  940.40179803  976.25310559  997.85507658 1013.47118719]
# [ 9.40056946 23.57652001 24.47533695 25.01691323 25.40841986]
# [0.94912463 2.38039365 2.47114233 2.52582236 2.56535066]
# /tmp/ipykernel_907/1364402294.py:74: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   pred = mod.params[0]+mod.params[1]*Xq[0,:]+mod.params[2]*Xq[1,:]+mod.params[3]*Xq[2,:]+mod.params[4]*Xq[3,:]
# /tmp/ipykernel_907/1364402294.py:89: UserWarning: This figure was using a layout engine that is incompatible with subplots_adjust and/or tight_layout; not calling subplots_adjust.
#   fig.subplots_adjust(wspace=0.05)

# %% [markdown]
# ## Above analysis illustrates a model including data from all sites including Miami.

# %% [markdown]
# However the Jaque-Bera statistic on any of the tested models, and the distribution testing on the selected performant model point to a non-Normal distribution of residuals which is not conducive to the purpose of the study in finding a model with normally distributed errors.

# %% [markdown]
# A deeper investigation as to why data including the Miami data indicates that observed discharge throughout the system is influenced by the control of flow through canals so that discharge represents a bimodal distribution.

# %%
for site,this in miami.groupby('site_no'):
    fig,ax=plt.subplots(1,1)
    ax.hist(np.log(this["Q_m3s"]))
    
    ax.set_title(site)

# %% [markdown]
# Apparent from the plot of mobilization distance versus discharge, all sites in Miami seem to illustrate this behavior, a cluster of observations with negligible discharge (around $10^{-2}\ m^3\ s^{-1}$), and a cluster across a range of discharges consistent with other sites.  Mobilization distance spans a range of distances across both groups.  We take this to indicate that factors beyond observed discharge are important to controlling bottle mobilization in this system.  Moreover, it is likely that this indicates that other similarly managed systems of canals throughout the United States (e.g. other locations in Florida and the Gulf Coast) have additional controls on debris mobilization.  We hypothesize that additional sources of turbulence may dominate beyond streamflow in these systems (wind, boat traffic), factors that we do not consider throughout the remainder of the study.
#
# Therefore, we consider the development of a model without including data from Miami.

# %%
temp = lcdistclean.set_index("site_no",append=True).drop(columns=['Point_ID','level_0'])
temp = temp["len_m Q_m3s 41_42_43 22_23_24 sinuosity 52 95 82".split()]
temp = temp.rename(columns={"41_42_43":"forest","22_23_24":"urban","52":"schrub","95":"wetland","82":"crops"})
temp = temp.dropna()
temp["forest"] *= 0.01
temp["urban"] *= 0.01
temp["schrub"] *= 0.01
temp = temp.clip(lower=1e-7)
miami = temp.xs("miami",level=0)
# Make clean  - less Miami and short events
clean = temp.drop("miami",level=0)
clean = clean[clean["len_m"] > 8]

rormulas = [rormula 
       for formulas in Rormulas 
       for rormula in formulas]  # 

AICs=[]
BICs=[]
r2adjs=[]
jbs=[]
rormulas = [rormula 
       for formulas in Rormulas 
       for rormula in formulas]  # 

for formula in rormulas:
    robust_model = smf.rlm(formula,data=clean,missing='drop',M=sm.robust.norms.HuberT())
    #glm_model = smf.glm(formula,data=clean,missing='drop',family=sm.families.Gamma(link=sm.families.links.log()))
    robust_model = robust_model.fit()
    #glm_model = glm_model.fit()
    # wls flow
    #ols_model = smf.ols(formula,data=clean,missing='drop').fit()
    #wls_model = smf.wls(formula,data=clean,weights=1./(np.abs(ols_model.resid) + 1e-6),missing='drop').fit()
    
    
    # Assuming `robust_model` is your fitted RLM model
    # and `y` is your dependent variable (e.g., df['log_len_m'])
    
    # Number of observations and parameters
    n = robust_model.nobs
    k = robust_model.df_model + 1  # includes intercept
    #n = glm_model.nobs
    #k = glm_model.df_model + 1
    #n = wls_model.nobs
    #k = wls_model.df_model + 1
    
    # Residual sum of squares
    rss = np.sum(robust_model.resid ** 2)
    #rss = np.sum(glm_model.resid_response ** 2)
    #rss = np.sum(wls_model.resid ** 2)
    
    # AIC and BIC
    aic = n * np.log(rss / n) + 2 * k
    bic = n * np.log(rss / n) + k * np.log(n)
    
    # Adjusted R-squared
    y = np.log(clean['len_m'])
    y_mean = np.mean(y)
    tss = np.sum((y - y_mean) ** 2)
    r2 = 1 - rss / tss
    r2_adj = 1 - (1 - r2) * (n - 1) / (n - k)
    
    # Jarque-Bera test
    jb_stat, jb_pvalue,_,_ = sm.stats.stattools.jarque_bera(robust_model.resid)
    #jb_stat, jb_pvalue,_,_ = sm.stats.stattools.jarque_bera(glm_model.resid_response)
    #jb_stat, jb_pvalue,_,_ = sm.stats.stattools.jarque_bera(wls_model.resid)
    
    # Print results
    #print(f"AIC: {aic:.2f}")
    #print(f"BIC: {bic:.2f}")
    #print(f"Adjusted R-squared: {r2_adj:.4f}")
    #print(f"Jarque-Bera Statistic: {jb_stat:.4f}, p-value: {jb_pvalue:.4g}")

    
    #print(mod.summary())
    AICs.append(aic)
    BICs.append(bic)
    r2adjs.append(r2_adj)
    jbs.append(jb_pvalue)
regress_table = pd.DataFrame(index=range(len(rormulas)),data={"Formula":rormulas,"AIC":AICs,"BIC":BICs,"r2_adj":r2adjs,"Prob(Jarque-Bera)":jbs})

# %%
regress_table["formula"] = regress_table["Formula"].apply(lambda x: x.replace("np.log",""))
display(regress_table.drop(columns="Formula").sort_values("Prob(Jarque-Bera)",ascending=False).head(10))
display(regress_table.drop(columns="Formula").sort_values("BIC",ascending=True))
# Out:
#        AIC      BIC  r2_adj  Prob(Jarque-Bera)                                                                                                                 formula
# 12  970.60   994.26    0.29           1.97e-02                                                 (len_m) ~ (Q_m3s) + np.sqrt(forest) + (urban) + np.sqrt(forest):(urban)
# 11  968.02   996.42    0.29           1.08e-02                       (len_m) ~ (Q_m3s) + np.sqrt(forest) + (urban) + (Q_m3s):np.sqrt(forest) + np.sqrt(forest):(urban)
# 7   950.92   979.32    0.30           5.72e-03                               (len_m) ~ (Q_m3s) + np.sqrt(forest) + (urban) + (Q_m3s):(urban) + np.sqrt(forest):(urban)
# 10  951.55   984.68    0.30           4.31e-03     (len_m) ~ (Q_m3s) + np.sqrt(forest) + (urban) + (Q_m3s):np.sqrt(forest) + (Q_m3s):(urban) + np.sqrt(forest):(urban)
# 41  980.71  1009.11    0.28           3.88e-03                            (len_m) ~ (Q_m3s) + np.sqrt(forest) + (schrub) + (Q_m3s):(schrub) + np.sqrt(forest):(schrub)
# 44  981.50  1014.63    0.28           2.43e-03  (len_m) ~ (Q_m3s) + np.sqrt(forest) + (schrub) + (Q_m3s):np.sqrt(forest) + (Q_m3s):(schrub) + np.sqrt(forest):(schrub)
# 26  990.26  1018.66    0.27           2.39e-03                       (len_m) ~ (Q_m3s) + np.sqrt(forest) + (sinuosity) + (Q_m3s):np.sqrt(forest) + (Q_m3s):(sinuosity)
# 78  985.76  1018.89    0.27           2.32e-03     (len_m) ~ (Q_m3s) + np.sqrt(forest) + (crops) + (Q_m3s):np.sqrt(forest) + (Q_m3s):(crops) + np.sqrt(forest):(crops)
# 77  984.39  1012.79    0.27           1.93e-03                               (len_m) ~ (Q_m3s) + np.sqrt(forest) + (crops) + (Q_m3s):np.sqrt(forest) + (Q_m3s):(crops)
# 75  985.82  1014.22    0.27           1.77e-03                               (len_m) ~ (Q_m3s) + np.sqrt(forest) + (crops) + (Q_m3s):(crops) + np.sqrt(forest):(crops)
#         AIC      BIC    r2_adj  Prob(Jarque-Bera)                                                                                                              formula
# 7    950.92   979.32  3.03e-01           5.72e-03                            (len_m) ~ (Q_m3s) + np.sqrt(forest) + (urban) + (Q_m3s):(urban) + np.sqrt(forest):(urban)
# 10   951.55   984.68  3.03e-01           4.31e-03  (len_m) ~ (Q_m3s) + np.sqrt(forest) + (urban) + (Q_m3s):np.sqrt(forest) + (Q_m3s):(urban) + np.sqrt(forest):(urban)
# 6    965.20   988.86  2.90e-01           1.60e-03                                                      (len_m) ~ (Q_m3s) + np.sqrt(forest) + (urban) + (Q_m3s):(urban)
# 58   962.52   990.92  2.93e-01           3.37e-05                      (len_m) ~ (Q_m3s) + np.sqrt(forest) + (wetland) + (Q_m3s):(wetland) + np.sqrt(forest):(wetland)
# 9    964.65   993.05  2.92e-01           9.81e-04                            (len_m) ~ (Q_m3s) + np.sqrt(forest) + (urban) + (Q_m3s):np.sqrt(forest) + (Q_m3s):(urban)
# ..      ...      ...       ...                ...                                                                                                                  ...
# 13  1184.58  1194.05  7.52e-02           3.88e-11                                                                                                    (len_m) ~ (urban)
# 81  1191.32  1200.78  6.77e-02           2.88e-10                                                                                                    (len_m) ~ (crops)
# 47  1207.99  1217.46  4.90e-02           3.01e-14                                                                                                   (len_m) ~ (schrub)
# 64  1235.81  1245.27  1.70e-02           9.46e-16                                                                                                  (len_m) ~ (wetland)
# 30  1246.82  1256.29  4.04e-03           4.82e-16                                                                                                (len_m) ~ (sinuosity)
#
# [85 rows x 5 columns]

# %%
temp = lcdistclean.set_index("site_no",append=True).drop(columns=['Point_ID','level_0'])
temp = temp["len_m Q_m3s 41_42_43 22_23_24 sinuosity 52 95 82".split()]
temp = temp.rename(columns={"41_42_43":"forest","22_23_24":"urban","52":"schrub","95":"wetland","82":"crops"})
temp = temp.dropna()
temp["forest"] *= 0.01
temp["urban"] *= 0.01
temp = temp.clip(lower=1e-7)
miami = temp.xs("miami",level=0)
# Make clean  - less Miami and short events
clean = temp.drop("miami",level=0)
clean = clean[clean["len_m"] > 8]

rormulas = Rormulas[0] # Best models all include urban as tertiary variable

AICs=[]
BICs=[]
r2adjs=[]
jbs=[]  # 

for formula in rormulas:
    robust_model = smf.rlm(formula,data=clean,missing='drop',M=sm.robust.norms.HuberT())
    #glm_model = smf.glm(formula,data=clean,missing='drop',family=sm.families.Gamma(link=sm.families.links.log()))
    robust_model = robust_model.fit()
    #glm_model = glm_model.fit()
    # wls flow
    #ols_model = smf.ols(formula,data=clean,missing='drop').fit()
    #wls_model = smf.wls(formula,data=clean,weights=1./(np.abs(ols_model.resid) + 1e-6),missing='drop').fit()
    
    
    # Assuming `robust_model` is your fitted RLM model
    # and `y` is your dependent variable (e.g., df['log_len_m'])
    
    # Number of observations and parameters
    n = robust_model.nobs
    k = robust_model.df_model + 1  # includes intercept
    #n = glm_model.nobs
    #k = glm_model.df_model + 1
    #n = wls_model.nobs
    #k = wls_model.df_model + 1
    
    # Residual sum of squares
    rss = np.sum(robust_model.resid ** 2)
    #rss = np.sum(glm_model.resid_response ** 2)
    #rss = np.sum(wls_model.resid ** 2)
    
    # AIC and BIC
    aic = n * np.log(rss / n) + 2 * k
    bic = n * np.log(rss / n) + k * np.log(n)
    
    # Adjusted R-squared
    y = np.log(clean['len_m'])
    y_mean = np.mean(y)
    tss = np.sum((y - y_mean) ** 2)
    r2 = 1 - rss / tss
    r2_adj = 1 - (1 - r2) * (n - 1) / (n - k)
    
    # Jarque-Bera test
    jb_stat, jb_pvalue,_,_ = sm.stats.stattools.jarque_bera(robust_model.resid)
    #jb_stat, jb_pvalue,_,_ = sm.stats.stattools.jarque_bera(glm_model.resid_response)
    #jb_stat, jb_pvalue,_,_ = sm.stats.stattools.jarque_bera(wls_model.resid)
    
    # Print results
    #print(f"AIC: {aic:.2f}")
    #print(f"BIC: {bic:.2f}")
    #print(f"Adjusted R-squared: {r2_adj:.4f}")
    #print(f"Jarque-Bera Statistic: {jb_stat:.4f}, p-value: {jb_pvalue:.4g}")

    
    #print(mod.summary())
    AICs.append(aic)
    BICs.append(bic)
    r2adjs.append(r2_adj)
    jbs.append(jb_pvalue)
regress_table = pd.DataFrame(index=range(len(rormulas)),data={"Formula":rormulas,"AIC":AICs,"BIC":BICs,"r2_adj":r2adjs,"Prob(Jarque-Bera)":jbs})

# %%
regress_table["formula"] = regress_table["Formula"].apply(lambda x: x.replace("np.log",""))
display(regress_table.drop(columns="Formula").sort_values("Prob(Jarque-Bera)",ascending=False).head(10))
display(regress_table.drop(columns="Formula").sort_values("BIC",ascending=True))
# Out:
#        AIC      BIC  r2_adj  Prob(Jarque-Bera)                                                                                                              formula
# 12  970.60   994.26    0.29           1.97e-02                                              (len_m) ~ (Q_m3s) + np.sqrt(forest) + (urban) + np.sqrt(forest):(urban)
# 11  968.02   996.42    0.29           1.08e-02                    (len_m) ~ (Q_m3s) + np.sqrt(forest) + (urban) + (Q_m3s):np.sqrt(forest) + np.sqrt(forest):(urban)
# 7   950.92   979.32    0.30           5.72e-03                            (len_m) ~ (Q_m3s) + np.sqrt(forest) + (urban) + (Q_m3s):(urban) + np.sqrt(forest):(urban)
# 10  951.55   984.68    0.30           4.31e-03  (len_m) ~ (Q_m3s) + np.sqrt(forest) + (urban) + (Q_m3s):np.sqrt(forest) + (Q_m3s):(urban) + np.sqrt(forest):(urban)
# 8   985.98  1009.65    0.27           1.73e-03                                              (len_m) ~ (Q_m3s) + np.sqrt(forest) + (urban) + (Q_m3s):np.sqrt(forest)
# 5   986.83  1005.77    0.27           1.71e-03                                                                        (len_m) ~ (Q_m3s) + np.sqrt(forest) + (urban)
# 6   965.20   988.86    0.29           1.60e-03                                                      (len_m) ~ (Q_m3s) + np.sqrt(forest) + (urban) + (Q_m3s):(urban)
# 9   964.65   993.05    0.29           9.81e-04                            (len_m) ~ (Q_m3s) + np.sqrt(forest) + (urban) + (Q_m3s):np.sqrt(forest) + (Q_m3s):(urban)
# 4   999.31  1018.25    0.26           4.16e-04                                                        (len_m) ~ (Q_m3s) + np.sqrt(forest) + (Q_m3s):np.sqrt(forest)
# 3   998.85  1013.05    0.26           3.37e-04                                                                                  (len_m) ~ (Q_m3s) + np.sqrt(forest)
#         AIC      BIC  r2_adj  Prob(Jarque-Bera)                                                                                                              formula
# 7    950.92   979.32    0.30           5.72e-03                            (len_m) ~ (Q_m3s) + np.sqrt(forest) + (urban) + (Q_m3s):(urban) + np.sqrt(forest):(urban)
# 10   951.55   984.68    0.30           4.31e-03  (len_m) ~ (Q_m3s) + np.sqrt(forest) + (urban) + (Q_m3s):np.sqrt(forest) + (Q_m3s):(urban) + np.sqrt(forest):(urban)
# 6    965.20   988.86    0.29           1.60e-03                                                      (len_m) ~ (Q_m3s) + np.sqrt(forest) + (urban) + (Q_m3s):(urban)
# 9    964.65   993.05    0.29           9.81e-04                            (len_m) ~ (Q_m3s) + np.sqrt(forest) + (urban) + (Q_m3s):np.sqrt(forest) + (Q_m3s):(urban)
# 12   970.60   994.26    0.29           1.97e-02                                              (len_m) ~ (Q_m3s) + np.sqrt(forest) + (urban) + np.sqrt(forest):(urban)
# 11   968.02   996.42    0.29           1.08e-02                    (len_m) ~ (Q_m3s) + np.sqrt(forest) + (urban) + (Q_m3s):np.sqrt(forest) + np.sqrt(forest):(urban)
# 5    986.83  1005.77    0.27           1.71e-03                                                                        (len_m) ~ (Q_m3s) + np.sqrt(forest) + (urban)
# 8    985.98  1009.65    0.27           1.73e-03                                              (len_m) ~ (Q_m3s) + np.sqrt(forest) + (urban) + (Q_m3s):np.sqrt(forest)
# 3    998.85  1013.05    0.26           3.37e-04                                                                                  (len_m) ~ (Q_m3s) + np.sqrt(forest)
# 4    999.31  1018.25    0.26           4.16e-04                                                        (len_m) ~ (Q_m3s) + np.sqrt(forest) + (Q_m3s):np.sqrt(forest)
# 2   1011.96  1030.89    0.25           7.15e-05                                                                        (len_m) ~ (Q_m3s) + (urban) + (Q_m3s):(urban)
# 1   1021.44  1035.64    0.24           2.51e-04                                                                                          (len_m) ~ (Q_m3s) + (urban)
# 0   1081.35  1090.82    0.18           8.90e-07                                                                                                    (len_m) ~ (Q_m3s)
# 16  1126.71  1145.64    0.14           2.01e-08                                                        (len_m) ~ np.sqrt(forest) + (urban) + np.sqrt(forest):(urban)
# 15  1132.15  1146.35    0.13           2.69e-10                                                                                  (len_m) ~ np.sqrt(forest) + (urban)
# 14  1141.90  1151.36    0.12           6.27e-11                                                                                            (len_m) ~ np.sqrt(forest)
# 13  1184.58  1194.05    0.08           3.88e-11                                                                                                    (len_m) ~ (urban)

# %%
best_idx = 12
formula = rormulas[best_idx]
print(formula)
print("AIC: {:0.1f}, BIC: {:0.1f}, r2adj: {:0.3f}, P(jb): {:0.3f}".format(AICs[best_idx], BICs[best_idx], r2adjs[best_idx], jbs[best_idx]))

mod = smf.rlm(formula,data=clean,missing='drop',M=sm.robust.norms.HuberT())
#glm_model = smf.glm(formula,data=clean,missing='drop',family=sm.families.Gamma(link=sm.families.links.log()))
#ols_model = smf.ols(formula,data=clean,missing='drop').fit()
#wls_model = smf.wls(formula,data=clean,missing='drop',weights=1./(np.abs(ols_model.resid) + 1e-6))


# Create design matrices
y, X = dmatrices(formula, data=clean, return_type='dataframe')
print(X.shape)
print("VIFs: ")
print([(X.iloc[:,i].name,vif(X,i)) for i in range(X.shape[1]) ])

mod = mod.fit()
mod.resid.hist()
print(mod.summary())

#glm_model = glm_model.fit()
#wls_model = wls_model.fit()
#print(dir(glm_model))
#wls_model.resid.hist().plot()
# Out:
# np.log(len_m) ~ np.log(Q_m3s) + np.sqrt(forest) + np.log(urban) + np.sqrt(forest):np.log(urban)
# AIC: 970.6, BIC: 994.3, r2adj: 0.286, P(jb): 0.020
# (840, 5)
# VIFs:
# [('Intercept', 22.20854446238042), ('np.log(Q_m3s)', 1.0430361721758779), ('np.sqrt(forest)', 5.493430249537214), ('np.log(urban)', 7.163132577132308), ('np.sqrt(forest):np.log(urban)', 16.076603420108682)]
#                     Robust linear Model Regression Results
# ==============================================================================
# Dep. Variable:          np.log(len_m)   No. Observations:                  840
# Model:                            RLM   Df Residuals:                      835
# Method:                          IRLS   Df Model:                            4
# Norm:                          HuberT
# Scale Est.:                       mad
# Cov Type:                          H1
# Date:                Mon, 20 Jul 2026
# Time:                        10:04:08
# No. Iterations:                    16
# =================================================================================================
#                                     coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# Intercept                         7.5709      0.310     24.451      0.000       6.964       8.178
# np.log(Q_m3s)                     0.4356      0.031     13.946      0.000       0.374       0.497
# np.sqrt(forest)                  -7.5994      1.121     -6.779      0.000      -9.797      -5.402
# np.log(urban)                     2.4719      0.404      6.121      0.000       1.680       3.263
# np.sqrt(forest):np.log(urban)    -5.5624      1.194     -4.660      0.000      -7.902      -3.223
# =================================================================================================
#
# If the model instance has been used for another fit with different fit parameters, then the fit options might not be the correct ones anymore .

# %%
mod.wald_test("np.log(Q_m3s) = 0")
# Out:
# /home/shan/.pyenv/versions/3.11.9/lib/python3.11/site-packages/statsmodels/base/model.py:1912: FutureWarning: The behavior of wald_test will change after 0.14 to returning scalar test statistic values. To get the future behavior now, set scalar to True. To silence this message while retaining the legacy behavior, set scalar to False.
#   warnings.warn(
# <class 'statsmodels.stats.contrast.ContrastResults'>
# <Wald test (chi2): statistic=[[194.5022898]], p-value=3.3085466360534733e-44, df_denom=1>

# %%
fig = sm.graphics.plot_partregress_grid(mod)
fig.tight_layout(pad=0.5)
fig.set_size_inches((12,8))

# %%
print(mod.sresid)
# Out:
# watershed  Asset           dt                         site_no
# chicago    Caleb           2022-11-17 04:10:10-06:00  05535000   -1.54
#            Cassidy         2022-10-26 11:10:08-05:00  05535000    1.15
#                            2022-10-29 17:09:55-05:00  05535000   -0.13
#                            2022-10-31 05:00:39-05:00  05535000    0.06
#                            2022-10-31 17:22:35-05:00  05535000   -1.03
#                                                                   ...
# socal      Periwinkle_1_0  2024-01-20 18:10:49-08:00  11048600    1.24
#            Periwinkle_1_1  2024-02-05 06:00:50-08:00  11048600    0.48
#                            2024-02-07 09:58:50-08:00  11048600   -1.12
#                            2024-02-08 09:51:31-08:00  11048600   -1.27
#                            2024-02-09 13:58:32-08:00  11048600   -1.13
# Length: 840, dtype: float64

# %%
from scipy import stats
# Residuals from robust regression
#residuals = glm_model.resid_response
#residuals = wls_model.resid
residuals = mod.resid

# Candidate distributions
candidates = [stats.norm, stats.t, stats.laplace, stats.cauchy, stats.skewnorm,stats.lognorm]

# Fit and test each distribution
for dist in candidates:
    params = dist.fit(residuals)
    ks_stat, ks_pvalue = stats.kstest(residuals, dist.name, args=params)
    print(f"Distribution: {dist.name}")
    print(f"Parameters: {params}")
    print(f"KS Statistic: {ks_stat:.4f}, p-value: {ks_pvalue:.4g}\n")
# Out:
# Distribution: norm
# Parameters: (0.012353653833794538, 1.7713809816131474)
# KS Statistic: 0.0329, p-value: 0.3162
#
# Distribution: t
# Parameters: (146686566392.13803, 0.012353385080848354, 1.7713804057325935)
# KS Statistic: 0.0329, p-value: 0.3162
#
# Distribution: laplace
# Parameters: (-0.04640217529044355, 1.4530638442306614)
# KS Statistic: 0.0636, p-value: 0.002148
#
# Distribution: cauchy
# Parameters: (-0.07454678483349958, 1.1530827496099318)
# KS Statistic: 0.0915, p-value: 1.445e-06
#
# Distribution: skewnorm
# Parameters: (0.8251630817764036, -1.0327171915322413, 2.056690378736577)
# KS Statistic: 0.0307, p-value: 0.401
# /home/shan/.pyenv/versions/3.11.9/lib/python3.11/site-packages/scipy/stats/_continuous_distns.py:6547: RuntimeWarning: invalid value encountered in log
#   lndata = np.log(data - loc)
# Distribution: lognorm
# Parameters: (0.04494561853103404, -39.392302323731016, 39.36472819594598)
# KS Statistic: 0.0301, p-value: 0.4228

# %%
def get_color(uniques,cmap="tab20b"):
    
    cm=mpl.colormaps[cmap]
    uniqdict=dict((unique,cm(float(j)/len(uniques))) for unique,j in zip(uniques,range(len(uniques))))
    return uniqdict

def get_marker(uniques):
    markers=["o","v","^","s","p","D","*"]
    uniqdict=dict((unique,markers[j]) for unique,j in zip(uniques,range(len(uniques))))
    return uniqdict

dist_cutoff = 8

temp = lcdistclean.set_index("site_no",append=True).drop(columns=['Point_ID','level_0'])
temp = temp["len_m Q_m3s 41_42_43 22_23_24 sinuosity 52 95 82".split()]
temp = temp.rename(columns={"41_42_43":"forest","22_23_24":"urban","52":"schrub","95":"wetland","82":"crops"})
temp = temp.dropna()
temp["forest"] *= 0.01
temp["urban"] *= 0.01
temp = temp.clip(lower=1e-7)
miami = temp.xs("miami",level=0)
# Make clean  - less Miami and short events
clean = temp.drop("miami",level=0)
lows = clean[clean["len_m"] <= dist_cutoff]
clean = clean[clean["len_m"] > dist_cutoff]

wseds = ['sfbay', 'socal', 'chicago','don', 'anacostia',  'ipswich', 'miami']

color_dict=get_color(wseds)
marker_dict=get_marker(wseds)
print(color_dict)
fig,axs=plt.subplots(1,1,dpi=300,sharey="row",figsize=(5,4),constrained_layout=True) 
axs=[axs]
for j,ax in enumerate(axs):

    def get_plabel(x):
        return ws_names[x]
    for site in wseds:
        if site == "miami":
            continue
        dist = clean.xs(site,level=0)

        print(get_plabel(site))
        dist.plot(ax=ax,x="Q_m3s",y="len_m",marker=marker_dict[site],c=color_dict[site],mec='k',ms=5,mew=0.15,ls="none",logx=False,logy=False,label=get_plabel(site))
        
    (lo,hi)=ax.get_xlim()
    lo,hi = 5e-5,5e3
    X=np.linspace(np.log(lo),np.log(hi),5)
    print(np.exp(X))
    (yo,yi)=ax.get_ylim()
    yo,yi = 5e0,5e4    
    if j==1:
        miami.plot(ax=ax,x="Q_m3s",y="len_m",marker='x',c=color_dict["miami"],ls="none",logx=False,logy=False,ms=5,label="Miami")
        ax.get_legend().remove()
        for site,dist in lows.groupby(level=0):
            dist.plot(ax=ax,x="Q_m3s",y="len_m",marker='x',c=color_dict[site],ls="none",logx=False,logy=False,ms=5,legend=False)
    else:
        ax.get_legend().remove()
        (handles,labels) = ax.get_legend_handles_labels()

        qs_1 = clean["forest"].quantile([0.05,0.5,0.95]).clip(lower=1e-9)
        qs_2 = clean["urban"].quantile([0.5])
        ps = ["{:0.0f}% forest".format(100.*q) for q in qs_1]
        lss = [":","--","-"]
        lcs = ["0.5","0.5","k"]
        print(qs_1)
        print(qs_2)
        for k,q in enumerate(qs_1):
            Xq = np.stack((X,(q**.5)*np.ones_like(X),np.log(qs_2.values)*np.ones_like(X),(q**.5)*np.log(qs_2.values)*np.ones_like(X)))
            print(Xq[3,:])
            if len(mod.params) > 2:
                
                pred = mod.params[0]+mod.params[1]*Xq[0,:]+mod.params[2]*Xq[1,:]+mod.params[3]*Xq[2,:]+mod.params[4]*Xq[3,:]
            else:
                pred = mod.params[0]+mod.params[1]*Xq[0,:]
            print("here")
            print(np.exp(pred))
            
            ax.plot(np.exp(X),np.exp(pred),ls=lss[k],color=lcs[k],label=ps[k])
    
    ax.set_xlim((lo,hi))
    ax.set_ylim((yo,yi))
    ax.set_xscale('log')
    ax.set_yscale('log')
    ax.set_ylabel("Mobilization distance (m)")
    ax.set_xlabel("Discharge ($m^3\ s^{-1}$)")
    #ax.text(0.025,0.95,"ab"[j]+")",transform=ax.transAxes)

fig.subplots_adjust(wspace=0.05)
legend1 = axs[0].legend(handles,labels,bbox_to_anchor=[0.05,-0.30,0.3,0.15],ncol=3,loc=2)
axs[0].add_artist(legend1)

lines = [mpl.lines.Line2D([],[],color=lc,ls=ls,label=p) for p,ls,lc in zip(ps,lss,lcs)]
legend2 = axs[0].legend(lines,ps,bbox_to_anchor=[0.05,0.85,0.4,0.1],loc=2,fontsize=8)
axs[0].add_artist(legend2)
# Out:
# {'sfbay': (0.2235294117647059, 0.23137254901960785, 0.4745098039215686, 1.0), 'socal': (0.4196078431372549, 0.43137254901960786, 0.8117647058823529, 1.0), 'chicago': (0.5490196078431373, 0.6352941176470588, 0.3215686274509804, 1.0), 'don': (0.5490196078431373, 0.42745098039215684, 0.19215686274509805, 1.0), 'anacostia': (0.9058823529411765, 0.796078431372549, 0.5803921568627451, 1.0), 'ipswich': (0.8392156862745098, 0.3803921568627451, 0.4196078431372549, 1.0), 'miami': (0.6470588235294118, 0.3176470588235294, 0.5803921568627451, 1.0)}
# Walnut
# S.California
# N.Chicago
# Don
# Anacostia
# Ipswich
# [5.e-05 5.e-03 5.e-01 5.e+01 5.e+03]
# 0.05    1.50e-03
# 0.50    1.04e-01
# 0.95    2.52e-01
# Name: forest, dtype: float64
# 0.5    0.49
# Name: urban, dtype: float64
# [-0.02791352 -0.02791352 -0.02791352 -0.02791352 -0.02791352]
# here
# [3.80335222e+00 2.82785250e+01 2.10255303e+02 1.56328142e+03
#  1.16232444e+04]
# [-0.23231472 -0.23231472 -0.23231472 -0.23231472 -0.23231472]
# here
# [1.37382566e+00 1.02146109e+01 7.59472470e+01 5.64679787e+02
#  4.19848347e+03]
# [-0.36172876 -0.36172876 -0.36172876 -0.36172876 -0.36172876]
# here
# [7.21001499e-01 5.36076012e+00 3.98580989e+01 2.96351265e+02
#  2.20341850e+03]
# /tmp/ipykernel_907/4281916827.py:73: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   pred = mod.params[0]+mod.params[1]*Xq[0,:]+mod.params[2]*Xq[1,:]+mod.params[3]*Xq[2,:]+mod.params[4]*Xq[3,:]
# /tmp/ipykernel_907/4281916827.py:89: UserWarning: This figure was using a layout engine that is incompatible with subplots_adjust and/or tight_layout; not calling subplots_adjust.
#   fig.subplots_adjust(wspace=0.05)

# %%
def get_color(uniques,cmap="terrain"):   
    cm=mpl.colormaps[cmap]
    uniqdict=dict((unique,cm(float(j)/len(uniques))) for unique,j in zip(uniques,range(len(uniques))))
    return uniqdict

dist_cutoff = 8

temp = lcdistclean.set_index("site_no",append=True).drop(columns=['Point_ID','level_0'])
temp = temp["len_m Q_m3s 41_42_43 22_23_24 sinuosity 52 95 82".split()]
temp = temp.rename(columns={"41_42_43":"forest","22_23_24":"urban","52":"schrub","95":"wetland","82":"crops"})
temp = temp.dropna()
temp["forest"] *= 0.01
temp["urban"] *= 0.01
temp = temp.clip(lower=1e-7)
miami = temp.xs("miami",level=0)
# Make clean  - less Miami and short events
clean = temp.drop("miami",level=0)
lows = clean[clean["len_m"] <= dist_cutoff]
clean = clean[clean["len_m"] > dist_cutoff]

wseds = ['sfbay', 'socal', 'chicago','don', 'anacostia',  'ipswich', 'miami']

color_dict=get_color(wseds)
print(color_dict)
fig,axs=plt.subplots(1,1,dpi=300,sharey="row",figsize=(5,4),constrained_layout=True)  
axs=[axs]
for j,ax in enumerate(axs):

    def get_plabel(x):
        return ws_names[x]
    for site in wseds:
        if site == "miami":
            continue
        dist = clean.xs(site,level=0)

        print(get_plabel(site))
        dist.plot(ax=ax,x="Q_m3s",y="len_m",marker=".",c=color_dict[site],mec='k',mew=0.09,ls="none",logx=False,logy=False,label=get_plabel(site))
        
    (lo,hi)=ax.get_xlim()
    lo,hi = 5e-5,5e3
    X=np.log(np.linspace(lo,hi,5))
    (yo,yi)=ax.get_ylim()
    yo,yi = 5e0,5e4    
    if j==0:
        miami.plot(ax=ax,x="Q_m3s",y="len_m",marker='x',c=color_dict["miami"],ls="none",logx=False,logy=False,ms=3,label="Miami")
        (handles,labels) = ax.get_legend_handles_labels() #(bbox_to_anchor=[0.05,1.01,0.9,0.15],ncol=4)
        ax.get_legend().remove()
        for site,dist in lows.groupby(level=0):
            dist.plot(ax=ax,x="Q_m3s",y="len_m",marker='x',c=color_dict[site],ls="none",logx=False,logy=False,ms=3,legend=False)    
    ax.set_xlim((lo,hi))
    ax.set_ylim((yo,yi))
    ax.set_xscale('log')
    ax.set_yscale('log')
    ax.set_ylabel("Mobilization distance (m)")
    ax.set_xlabel("Discharge ($m^3\ s^{-1}$)")
    #ax.text(0.025,0.95,"ab"[j]+")",transform=ax.transAxes)

fig.subplots_adjust(wspace=0.05)
legend1 = axs[0].legend(handles,labels,bbox_to_anchor=[0.05,-0.30,0.3,0.15],ncol=3,loc=2)
axs[0].add_artist(legend1)
# Out:
# {'sfbay': (0.2, 0.2, 0.6, 1.0), 'socal': (0.011764705882352955, 0.5764705882352941, 0.9764705882352941, 1.0), 'chicago': (0.1450980392156863, 0.8290196078431373, 0.42901960784313725, 1.0), 'don': (0.7098039215686275, 0.9419607843137255, 0.5419607843137255, 1.0), 'anacostia': (0.8549019607843137, 0.8142745098039216, 0.5216470588235294, 1.0), 'ipswich': (0.5725490196078431, 0.45286274509803925, 0.36917647058823533, 1.0), 'miami': (0.7176470588235294, 0.6385882352941177, 0.6216470588235294, 1.0)}
# Walnut
# S.California
# N.Chicago
# Don
# Anacostia
# Ipswich
# /tmp/ipykernel_907/440902511.py:58: UserWarning: This figure was using a layout engine that is incompatible with subplots_adjust and/or tight_layout; not calling subplots_adjust.
#   fig.subplots_adjust(wspace=0.05)

# %% [markdown]
# #### How sensitive is the model to the six models included in designing the final model?
#
# Going to use a leave one group out validation strategy a la Roberts et al., 2016, Ecography.

# %%
best_idx = 12
formula = rormulas[best_idx]
print(formula)
print("AIC: {:0.1f}, BIC: {:0.1f}, r2adj: {:0.3f}, P(jb): {:0.3f}".format(AICs[best_idx], BICs[best_idx], r2adjs[best_idx], jbs[best_idx]))

dist_cutoff = 8

temp = lcdistclean.set_index("site_no",append=True).drop(columns=['Point_ID','level_0'])
temp = temp["len_m Q_m3s 41_42_43 22_23_24 sinuosity 52 95 82".split()]
temp = temp.rename(columns={"41_42_43":"forest","22_23_24":"urban","52":"schrub","95":"wetland","82":"crops"})
temp = temp.dropna()
temp["forest"] *= 0.01
temp["urban"] *= 0.01
temp = temp.clip(lower=1e-7)
miami = temp.xs("miami",level=0)
# Make clean  - less Miami and short events
clean = temp.drop("miami",level=0)
lows = clean[clean["len_m"] <= dist_cutoff]
clean = clean[clean["len_m"] > dist_cutoff]

wseds = ['sfbay', 'socal', 'chicago','don', 'anacostia',  'ipswich', 'miami']
color_dict=get_color(wseds)

def rmse(y_est,y_obs):
    return np.mean((y_est-y_obs)**2)**0.5

cv_events={}
for wsed in wseds[:-1]:
    test = clean.xs(wsed,level=0)
    train = clean.drop(wsed,level=0)
   
    cv_mod = smf.rlm(formula,data=train,missing='drop',M=sm.robust.norms.HuberT())
    #glm_model = smf.glm(formula,data=clean,missing='drop',family=sm.families.Gamma(link=sm.families.links.log()))
    #ols_model = smf.ols(formula,data=clean,missing='drop').fit()
    #wls_model = smf.wls(formula,data=clean,missing='drop',weights=1./(np.abs(ols_model.resid) + 1e-6))  
    cv_mod = cv_mod.fit()
    n = cv_mod.nobs
    k = cv_mod.df_model + 1  # includes intercept
   
    # Residual sum of squares
    rss = np.sum(cv_mod.resid ** 2)
    # AIC and BIC
    aic = n * np.log(rss / n) + 2 * k
    bic = n * np.log(rss / n) + k * np.log(n)
    
    # Adjusted R-squared
    y = np.log(train['len_m'])
    y_mean = np.mean(y)
    tss = np.sum((y - y_mean) ** 2)
    r2 = 1 - rss / tss
    r2_adj = 1 - (1 - r2) * (n - 1) / (n - k)
    
    # Jarque-Bera test
    jb_stat, jb_pvalue,_,_ = sm.stats.stattools.jarque_bera(cv_mod.resid)
    
    #mod.resid.hist(ax=ax,fig=fig)
    print(wsed)
    print(cv_mod.summary())
    #print(wsed," summary: ")
    #print("RSS: {:.4f} AIC: {:.4f} BIC: {:.4f} P(JB): {:.4f}".format(rss, aic, bic, jb_pvalue))

    rms=rmse(np.exp(cv_mod.predict(test)),test["len_m"])
    cv_events[wsed] = {"aic":aic,"bic":bic,"rss":rss,"r2_adj":r2_adj,"jb_pvalue":jb_pvalue,"rmse":rms}
    cv_events[wsed] = cv_events[wsed] | cv_mod.params.to_dict()
    
n = mod.nobs
k = mod.df_model + 1  # includes intercept

# Residual sum of squares
rss = np.sum(mod.resid ** 2)
# AIC and BIC
aic = n * np.log(rss / n) + 2 * k
bic = n * np.log(rss / n) + k * np.log(n)

# Adjusted R-squared
y = np.log(clean['len_m'])
y_mean = np.mean(y)
tss = np.sum((y - y_mean) ** 2)
r2 = 1 - rss / tss
r2_adj = 1 - (1 - r2) * (n - 1) / (n - k)

# Jarque-Bera test
jb_stat, jb_pvalue,_,_ = sm.stats.stattools.jarque_bera(mod.resid)
rms=rmse(np.exp(mod.predict(test)),clean["len_m"])
cv_events["clean"] = {"aic":aic,"bic":bic,"rss":rss,"r2_adj":r2_adj,"jb_pvalue":jb_pvalue,"rmse":rms}
cv_events["clean"] = cv_events["clean"] | mod.params.to_dict()
# Out:
# np.log(len_m) ~ np.log(Q_m3s) + np.sqrt(forest) + np.log(urban) + np.sqrt(forest):np.log(urban)
# AIC: 970.6, BIC: 994.3, r2adj: 0.286, P(jb): 0.020
# sfbay
#                     Robust linear Model Regression Results
# ==============================================================================
# Dep. Variable:          np.log(len_m)   No. Observations:                  765
# Model:                            RLM   Df Residuals:                      760
# Method:                          IRLS   Df Model:                            4
# Norm:                          HuberT
# Scale Est.:                       mad
# Cov Type:                          H1
# Date:                Mon, 20 Jul 2026
# Time:                        11:02:07
# No. Iterations:                    19
# =================================================================================================
#                                     coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# Intercept                         7.7031      0.313     24.648      0.000       7.091       8.316
# np.log(Q_m3s)                     0.4515      0.034     13.221      0.000       0.385       0.518
# np.sqrt(forest)                  -8.5775      1.153     -7.438      0.000     -10.838      -6.317
# np.log(urban)                     2.5468      0.415      6.143      0.000       1.734       3.359
# np.sqrt(forest):np.log(urban)    -6.2114      1.230     -5.049      0.000      -8.623      -3.800
# =================================================================================================
#
# If the model instance has been used for another fit with different fit parameters, then the fit options might not be the correct ones anymore .
# socal
#                     Robust linear Model Regression Results
# ==============================================================================
# Dep. Variable:          np.log(len_m)   No. Observations:                  665
# Model:                            RLM   Df Residuals:                      660
# Method:                          IRLS   Df Model:                            4
# Norm:                          HuberT
# Scale Est.:                       mad
# Cov Type:                          H1
# Date:                Mon, 20 Jul 2026
# Time:                        11:02:07
# No. Iterations:                    15
# =================================================================================================
#                                     coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# Intercept                         4.1264      0.435      9.478      0.000       3.273       4.980
# np.log(Q_m3s)                     0.4878      0.033     14.809      0.000       0.423       0.552
# np.sqrt(forest)                   3.2401      1.422      2.278      0.023       0.452       6.028
# np.log(urban)                    -0.7642      0.708     -1.080      0.280      -2.151       0.623
# np.sqrt(forest):np.log(urban)     4.0014      1.668      2.399      0.016       0.733       7.270
# =================================================================================================
#
# If the model instance has been used for another fit with different fit parameters, then the fit options might not be the correct ones anymore .
# chicago
#                     Robust linear Model Regression Results
# ==============================================================================
# Dep. Variable:          np.log(len_m)   No. Observations:                  763
# Model:                            RLM   Df Residuals:                      758
# Method:                          IRLS   Df Model:                            4
# Norm:                          HuberT
# Scale Est.:                       mad
# Cov Type:                          H1
# Date:                Mon, 20 Jul 2026
# Time:                        11:02:07
# No. Iterations:                    18
# =================================================================================================
#                                     coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# Intercept                         7.9409      0.311     25.565      0.000       7.332       8.550
# np.log(Q_m3s)                     0.4353      0.032     13.740      0.000       0.373       0.497
# np.sqrt(forest)                  -8.4240      1.113     -7.568      0.000     -10.606      -6.242
# np.log(urban)                     2.7302      0.402      6.797      0.000       1.943       3.518
# np.sqrt(forest):np.log(urban)    -6.1100      1.187     -5.148      0.000      -8.436      -3.784
# =================================================================================================
#
# If the model instance has been used for another fit with different fit parameters, then the fit options might not be the correct ones anymore .
# don
#                     Robust linear Model Regression Results
# ==============================================================================
# Dep. Variable:          np.log(len_m)   No. Observations:                  665
# Model:                            RLM   Df Residuals:                      660
# Method:                          IRLS   Df Model:                            4
# Norm:                          HuberT
# Scale Est.:                       mad
# Cov Type:                          H1
# Date:                Mon, 20 Jul 2026
# Time:                        11:02:07
# No. Iterations:                    20
# =================================================================================================
#                                     coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# Intercept                         8.1926      0.320     25.596      0.000       7.565       8.820
# np.log(Q_m3s)                     0.4139      0.033     12.495      0.000       0.349       0.479
# np.sqrt(forest)                  -8.4177      1.204     -6.994      0.000     -10.777      -6.059
# np.log(urban)                     3.1479      0.417      7.550      0.000       2.331       3.965
# np.sqrt(forest):np.log(urban)    -6.5091      1.215     -5.355      0.000      -8.891      -4.127
# =================================================================================================
#
# If the model instance has been used for another fit with different fit parameters, then the fit options might not be the correct ones anymore .
# anacostia
#                     Robust linear Model Regression Results
# ==============================================================================
# Dep. Variable:          np.log(len_m)   No. Observations:                  601
# Model:                            RLM   Df Residuals:                      596
# Method:                          IRLS   Df Model:                            4
# Norm:                          HuberT
# Scale Est.:                       mad
# Cov Type:                          H1
# Date:                Mon, 20 Jul 2026
# Time:                        11:02:08
# No. Iterations:                    14
# =================================================================================================
#                                     coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# Intercept                         8.0001      0.340     23.512      0.000       7.333       8.667
# np.log(Q_m3s)                     0.3342      0.034      9.868      0.000       0.268       0.401
# np.sqrt(forest)                  -9.1638      1.258     -7.286      0.000     -11.629      -6.699
# np.log(urban)                     2.5276      0.413      6.125      0.000       1.719       3.336
# np.sqrt(forest):np.log(urban)    -6.0616      1.240     -4.888      0.000      -8.492      -3.631
# =================================================================================================
#
# If the model instance has been used for another fit with different fit parameters, then the fit options might not be the correct ones anymore .
# ipswich
#                     Robust linear Model Regression Results
# ==============================================================================
# Dep. Variable:          np.log(len_m)   No. Observations:                  741
# Model:                            RLM   Df Residuals:                      736
# Method:                          IRLS   Df Model:                            4
# Norm:                          HuberT
# Scale Est.:                       mad
# Cov Type:                          H1
# Date:                Mon, 20 Jul 2026
# Time:                        11:02:08
# No. Iterations:                    14
# =================================================================================================
#                                     coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# Intercept                         7.9442      0.356     22.338      0.000       7.247       8.641
# np.log(Q_m3s)                     0.5154      0.037     13.885      0.000       0.443       0.588
# np.sqrt(forest)                  -9.3267      1.398     -6.672      0.000     -12.066      -6.587
# np.log(urban)                     3.1450      0.489      6.427      0.000       2.186       4.104
# np.sqrt(forest):np.log(urban)    -8.2118      1.695     -4.845      0.000     -11.534      -4.890
# =================================================================================================
#
# If the model instance has been used for another fit with different fit parameters, then the fit options might not be the correct ones anymore .

# %%
display(pd.DataFrame.from_dict(cv_events))
# Out:
#                                  sfbay     socal  chicago      don  anacostia  ipswich    clean
# aic                             895.35  6.52e+02   866.40   763.96   7.20e+02   879.78   970.60
# bic                             918.55  6.74e+02   889.59   786.46   7.42e+02   902.82   994.26
# rss                            2433.76  1.75e+03  2344.13  2066.40   1.96e+03  2396.56  2635.87
# r2_adj                            0.29  2.62e-01     0.31     0.31   2.79e-01     0.30     0.29
# jb_pvalue                         0.05  8.80e-03     0.16     0.24   2.12e-03     0.01     0.02
# rmse                           1426.56  4.29e+03   883.18   982.47   7.43e+02   104.42    98.80
# Intercept                         7.70  4.13e+00     7.94     8.19   8.00e+00     7.94     7.57
# np.log(Q_m3s)                     0.45  4.88e-01     0.44     0.41   3.34e-01     0.52     0.44
# np.sqrt(forest)                  -8.58  3.24e+00    -8.42    -8.42  -9.16e+00    -9.33    -7.60
# np.log(urban)                     2.55 -7.64e-01     2.73     3.15   2.53e+00     3.14     2.47
# np.sqrt(forest):np.log(urban)    -6.21  4.00e+00    -6.11    -6.51  -6.06e+00    -8.21    -5.56
